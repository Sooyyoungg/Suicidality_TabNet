# %% [markdown]
# # load libraries and data

# %%
from torch import nn
import torch
from torch import tensor 
from torch.autograd import Variable
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from pytorch_tabnet.tab_model import TabNetClassifier, TabNetRegressor
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import KFold
import torch
import itertools
from pytorch_tabnet.tab_model import TabNetClassifier
from sklearn.metrics import roc_auc_score, accuracy_score
from tqdm.notebook import tqdm
from pathlib import Path
import os

# psychosocial + rsfMRI + strurctural MRI + diffusion MRI

train_out = Path('./data/si_ppc_rsf_s_dMRI_train.csv')
test_out =Path('./data/si_ppc_rsf_s_dMRI_test.csv')

train_data= pd.read_csv(train_out)
test_data= pd.read_csv(test_out)

target ='Suicidalideation'
unused_feat = ['subjectkey', 'abcd_site']

# mri feature가 시작하는 column의 index 구하기
# np.where의 결과값이 array에 들어가기 때문에 방금 계산해 넣어놓은 [0]번째 값을 가져온다.
start_psycho_index = np.where(test_data.columns.values == "race.ethnicity_1")[0][0]
start_rsfmri_index = np.where(test_data.columns.values == "rsfmri_var_cort.destrieux_g.and.s.frontomargin.lh")[0][0]
start_structmri_index = np.where(test_data.columns.values == "lh_bankssts_area._.1")[0][0]
start_diffmri_index = np.where(test_data.columns.values == "con_L.BSTS_L.CACG_count")[0][0]

psychosocial = list(test_data.columns[start_psycho_index:start_rsfmri_index])
rsf_mri = list(test_data.columns[start_rsfmri_index:start_structmri_index])
structural_mri = list(test_data.columns[start_structmri_index:start_diffmri_index])
diffusion_mri = list(test_data.columns[start_diffmri_index:])

Num_FOLDS  = 5
# the number of feature that you want to show 
Num_feat = 20

print(len(train_data), len(train_data.columns))
print(len(psychosocial))
print(len(rsf_mri))
print(len(structural_mri))
print(len(diffusion_mri))
# Out:
# 5510 4750
# 129
# 148
# 984
# 3485

# %%
train_data['subjectkey']
#test_data['subjectkey']
# Out:
# 0       NDARINV003RTV85
# 1       NDARINV00BD7VDC
# 2       NDARINV00R4TXET
# 3       NDARINV00U4FTRU
# 4       NDARINV00UMK5VC
#              ...
# 5505    NDARINVZZJ3A7BK
# 5506    NDARINVZZLZCKAY
# 5507    NDARINVZZPKBDAC
# 5508    NDARINVZZZ2ALR6
# 5509    NDARINVZZZNB0XC
# Name: subjectkey, Length: 5510, dtype: object

# %% [markdown]
# # Fine object featrues

# %%
# reset_index(drop=True): index값 초기화 + drop으로 index 열 삭제
train_data_processed = train_data.fillna(0).reset_index(drop=True)

features = [col for col in train_data_processed.columns 
            if col not in unused_feat + [target] + rsf_mri + structural_mri + diffusion_mri and test_data[col].dtypes != 'object']
print(features)
# Out:
# ['Unnamed: 0', 'race.ethnicity_1', 'race.ethnicity_2', 'race.ethnicity_3', 'race.ethnicity_4', 'race.ethnicity_5', 'sex_1', 'sex_2', 'high.educ_1', 'high.educ_2', 'high.educ_3', 'high.educ_4', 'high.educ_5', 'high.educ_6', 'high.educ_7', 'high.educ_8', 'high.educ_9', 'high.educ_10', 'high.educ_11', 'high.educ_12', 'high.educ_13', 'high.educ_14', 'high.educ_15', 'high.educ_16', 'high.educ_17', 'high.educ_18', 'high.educ_19', 'income_1', 'income_2', 'income_3', 'income_4', 'income_5', 'income_6', 'income_7', 'income_8', 'income_9', 'income_10', 'married_1', 'married_2', 'married_3', 'married_4', 'married_5', 'married_6', 'fes_q1_1', 'fes_q1_2', 'fes_q2_1', 'fes_q2_2', 'fes_q3_1', 'fes_q3_2', 'fes_q4_1', 'fes_q4_2', 'fes_q5_1', 'fes_q5_2', 'fes_q6_1', 'fes_q6_2', 'fes_q7_1', 'fes_q7_2', 'fes_q8_1', 'fes_q8_2', 'fes_q9_1', 'fes_q9_2', 'height', 'weight', 'BMI', 'vol', 'age', 'nihtbx_totalcomp_uncorrected', 'nihtbx_fluidcomp_uncorrected', 'nihtbx_pattern_uncorrected', 'nihtbx_picture_uncorrected', 'nihtbx_list_uncorrected', 'nihtbx_flanker_uncorrected', 'nihtbx_cardsort_uncorrected', 'nihtbx_cryst_uncorrected', 'nihtbx_reading_uncorrected', 'nihtbx_picvocab_uncorrected', 'poa_total_6month_follow_up', 'friends', 'close_friends', 'upps_negative_urgency', 'upps_lack_of_planning', 'upps_sensation_seeking', 'upps_positive_urgency', 'upps_lack_of_perseverance', 'upps_total', 'AnxDep.CBCL', 'WithDep.CBCL', 'Somatic.CBCL', 'Social.CBCL', 'Thought.CBCL', 'Attention.CBCL', 'RuleBreak.CBCL', 'Aggressive.CBCL', 'Internal.CBCL', 'External.CBCL', 'TotProb.CBCL', 'Depress.CBCL', 'AnxDisord.CBCL', 'SomaticPr.CBCL', 'ADHD.CBCL', 'Opposit.CBCL', 'Conduct.CBCL', 'Sluggish.Cognitive.Tempo..SCT..CBCL', 'Obsessive.Compulsive.Problems..OCD..CBCL', 'Stress.CBCL', 'Internal.and.External.Comobidity', 'HC_PSD', 'HC_CHM', 'Ne_EN', 'Ne_PN', 'Ab_PA', 'HC_HSA', 'HC_MIH', 'Ab', 'HC', 'Ne', 'ELS_total', 'mania_score_1_year_follow_up', 'mania_binary_1_year_follow_up', 'DIMS_baseline', 'SH_baseline', 'SWTD_baseline', 'SBD_baseline', 'DA_baseline', 'DOES_baseline', 'totalSDS_baseline', 'totalBIS', 'totalBAS', 'PPSP_frequency', 'PPSP_distress']

# %% [markdown]
# # For getting feature importance

# %%
def feature(Num_feat, clf, test_data_processed, features):
    importance =clf.feature_importances_
    #plt.plot(importance)
    #plt.show()
    labels_importance=importance.argsort()[::-1]

    importance_sort = np.sort(importance)[::-1]

    feat_name_sort=test_data_processed[features].columns[labels_importance]
    important_features = pd.DataFrame() 
    
    for i in range (Num_feat):
        feature = pd.DataFrame([[feat_name_sort[i],importance_sort[i]]], columns = ['feature name', 'ratio'])
        important_features=pd.concat([important_features,feature])

    return important_features.reset_index(drop=True)

# %% [markdown]
# # Define function for preprocessing for Cross validation

# %%
def preprocessing (train_data, test_data, NUM_FOLDS):
    test_data_processed= test_data.fillna(0).reset_index(drop=True)
    train_data_processed = train_data.fillna(0).reset_index(drop=True)
    
    # 추가? 값 변경?
    test_data_processed["kfold"] = -1
    train_data_processed["kfold"] = -1

    # frac: 전체 row 중 몇 %를 반환할 지 결정 -> frac=1을 설정해서 모든 데이터를 반환
    # random_state: 추후 이것과 동일한 샘플링을 재현하기 위함
    # sample: 데이터에서 임의의 샘플 선정 -> frac=1이면 전체 data의 순서만 임의로 바뀜
    train_data_processed = train_data_processed.sample(frac=1,random_state=2020).reset_index(drop=True)

    kf = KFold(n_splits=NUM_FOLDS)
    # enumerate: 각 split된 data set 순서대로 index를 함께 반환
    for fold, (trn_, val_) in enumerate(kf.split(X=train_data_processed, y=train_data_processed)):
        #print(len(trn_), len(val_)) -> 출력: 4408, 1102
        train_data_processed.loc[val_, 'kfold'] = fold
    
    print("done preprocessing")
    return train_data_processed, test_data_processed

# %% [markdown]
# # Finding best parameters

# %%
# Augmented
import torch
import itertools
from sklearn.metrics import confusion_matrix
from pytorch_tabnet.tab_model import TabNetClassifier
from sklearn.metrics import roc_auc_score, accuracy_score
from tqdm.notebook import tqdm


def find_bestpar(fold, train_data_processed, test_data_processed, features):
    
    """test data 생성"""
    X_test = test_data_processed[features].values
    Y_test = test_data_processed[target].values
    
    # Store maximum auc
    max_auc= 0
    # Store maximum hypterparameter set
    max_hy = []
    
    # define hyperparameter space : learning rate, 
    n_ = [4,8,16]                              # 
    lr_ = [2e-2, 1e-2, 5e-3, 2e-3, 1e-3, 1e-4] # learning rate
    w_ = [0.01, 0.001, 0.0001]                 # weight decay
    g_ = [0.95, 0.99, 0.9]                     # scheduler params - gamma
    ss_ = [10, 20, 30]                         # scheduler params - step_size
    
    # Orginal hyperparameter space 
    """
    # define hyperparameter space (quick version)
    n_ = [4,8]
    lr_ = [2e-2,1e-2, 5e-3, 2e-3, 1e-3, 1e-4]
    w_ = [0.01, 0.001, 0.0001]
    g_ = [0.95, 0.99]
    ss_ = [10, 20]
    """
    all_ = [n_, lr_, w_, g_, ss_]
    h_space = [s for s in itertools.product(*all_)]
    
    for hy in tqdm(h_space):
        """===================Cross Validation==================="""
        
        """validation & test 결과"""
        valid_res = []
        test_auc_res = []
        test_acc_res = []

        for i in range(fold):
            #print("fold ", i)
            # 5개의 fold 사용했으므로 변수 fold 값은 차례대로 0,1,2,3,4 중 하나
            df_train = train_data_processed[train_data_processed.kfold != i]  # 5개 중 4개 train에 할당
            df_valid = train_data_processed[train_data_processed.kfold == i]  # 5개 중 1개 validation에 할당
            
            X_train = df_train[features].values
            Y_train = df_train[target].values
            
            X_valid = df_valid[features].values
            Y_valid = df_valid[target].values
            
            
            clf = TabNetClassifier(n_a = hy[0],
                                   n_d = hy[0],
                                   optimizer_params = dict(lr=hy[1], weight_decay=hy[2]),
                                   scheduler_params={"step_size":hy[4], "gamma":hy[3]},
                                   scheduler_fn=torch.optim.lr_scheduler.StepLR,
                                   verbose=0)

            clf.fit(X_train, Y_train, eval_set=[(X_train, Y_train), (X_valid, Y_valid)], 
                    eval_name=['train', 'valid'], eval_metric=['auc'],
                    max_epochs=200 , patience=20)
       
            preds_acc = clf.predict(X_test)
            preds_prob = clf.predict_proba(X_test)
            test_auc = roc_auc_score(y_score=preds_prob[:,1], y_true=Y_test)
            test_acc = accuracy_score(preds_acc, Y_test)
            
            valid_res.append(clf.best_cost)
            test_auc_res.append(test_auc)
            test_acc_res.append(test_acc)
            print('[%3d/%4d] '%(i+1, fold),'Valid score: %2f'% clf.best_cost, 'Test AUC: %.3f%%'%test_auc, 'Test ACC: %.3f%%'%test_acc)
    
        #print(valid_res)
        #print(test_auc_res)
        #print(test_acc_res)
        """valid와 test의 평균, 표준편차 출력"""
        print("=====parameter별 valid, test score=====")
        print("Validation 평균: %3f"%np.mean(valid_res), "Test AUC 평균: %3f"%np.mean(test_auc_res), "Test ACC 평균: %3f"%np.mean(test_acc_res))

        if np.mean(test_auc_res)>max_auc:
            print("Find new maximum AUC!!")
            max_hy = hy
            max_auc = np.mean(test_auc_res)
    
    return max_hy

# %% [markdown]
# # Train with best parameter

# %%
def bestpar_tuning(fold, train_data_processed, test_data_processed, max_hy, features):
 
    hy = max_hy
    print("Max hy:" ,hy)
    
    """validation & test 결과"""
    valid_res = []
    test_auc_res = []
    test_ac_resc = []
    
    for i in range(fold):
            # 5개의 fold 사용했으므로 변수 fold 값은 차례대로 0,1,2,3,4 중 하나
            df_train = train_data_processed[train_data_processed.kfold != i]  # 5개 중 4개 train에 할당
            df_valid = train_data_processed[train_data_processed.kfold == i]  # 5개 중 1개 validation에 할당
            
            X_train = df_train[features].values
            Y_train = df_train[target].values
            
            X_valid = df_valid[features].values
            Y_valid = df_valid[target].values
            
            
            clf = TabNetClassifier(n_a = hy[0],
                                   n_d = hy[0],
                                   optimizer_params = dict(lr=hy[1], weight_decay=hy[2]),
                                   scheduler_params={"step_size":hy[4], "gamma":hy[3]},
                                   scheduler_fn=torch.optim.lr_scheduler.StepLR,
                                   verbose=0)

            clf.fit(X_train, Y_train, eval_set=[(X_train, Y_train), (X_valid, Y_valid)], 
                        eval_name=['train', 'valid'], eval_metric=['auc'],
                        max_epochs=200 , patience=20)

            preds_acc = clf.predict(X_test)
            preds_prob = clf.predict_proba(X_test)
            test_auc = roc_auc_score(y_score=preds_prob[:,1], y_true=Y_test)
            test_acc = accuracy_score(preds_acc, Y_test)

            TN, FP, FN, TP = confusion_matrix(y_true=Y_test, y_pred = clf.predict(X_test)).ravel()
            sensitivity =TP/(TP+FN)
            specificity =TN/(TN+FP)
            PPV = TP/(TP+FP)
            NPV = TN/(TN+FN)
            Accuracy = TP+FP/(TN+ FP+ FN + TP)
            
            valid_res.append(clf.best_cost)
            test_auc_res.append(test_auc)
            test_acc_res.append(test_acc)
            print('[%3d/%4d] '%(i+1, fold),'Valid score: %2f'% clf.best_cost, 'Test AUC: %.3f%%'%test_auc, 'Test ACC: %.3f%%'%test_acc)

    """valid와 test의 평균, 표준편차 출력"""
    print("Validation 평균: %3f"%np.mean(valid_res), "Test AUC 평균: "%np.mean(test_auc_res), "Test ACC 평균: "%np.mean(test_acc_res))
    
    return test_auc, clf, preds_prob, sensitivity, specificity, PPV, NPV, Accuracy

# %% [markdown]
# # Run function, Split data and and cross validation. This needs to be modified

# %%
def run(train_data_processed, test_data_processed, fold, Num_feat, features):
    
    print("-------------------------------Training Begining-------------------------------")
    n_ = [4,8,16]
    lr_ = [2e-2, 1e-2, 5e-3, 2e-3, 1e-3, 1e-4]
    w_ = [0.01, 0.001, 0.0001]
    g_ = [0.95, 0.99, 0.9]
    ss_ = [10, 20, 30]
    all_ = [n_, lr_, w_, g_, ss_]
    h_space = [s for s in itertools.product(*all_)]
    
    # Start training
    max_hy = find_bestpar(fold, train_data_processed, test_data_processed, features)
    
    # if you want to just test the code, you should use this
    # max_hy = h_space[0]
    print("Found maximum hyperparmeter, now work with that")
    
    print("-------------------------------Testing Begining-------------------------------")
    test_auc, clf, preds_prob, sensitivity, specificity, PPV, NPV, Accuracy = bestpar_tuning(fold, train_data_processed, test_data_processed, max_hy, features)
    
    #print("-------------------------------Important Feature-------------------------------")
    import_feat=feature(Num_feat, clf, test_data_processed, features)
    preds_val_prob = clf.predict_proba(X_valid)

    return test_auc, Y_test, X_test, clf, preds_prob, import_feat, Y_valid, preds_val_prob

# %% [markdown]
# # Final training function

# %%
def hyperparametertuning_CV (train_data, test_data, target, unused_feat, Num_FOLDS, Num_feat):
    CV_auc_all = []
    import_feat_every = pd.DataFrame()
    
    # Data processing
    train_data_processed, test_data_processed = preprocessing (train_data, test_data, Num_FOLDS)
    
    features_rsf_only = [col for col in train_data_processed.columns if col in psychosocial + rsf_mri]
    
    print("rsf mri only")
    test_auc_rsf_only, Y_test_rsf_only, X_test_rsf_only, clf_rsf_only, preds_prob_rsf_only, import_feat_rsf_only, Y_valid_rsf_only, preds_val_prob_rsf_only = run(train_data_processed,
                                                                             test_data_processed,
                                                                             5, 
                                                                             Num_feat, 
                                                                             features_rsf_only)
        
    return test_auc_rsf_only, Y_test_rsf_only, X_test_rsf_only, clf_rsf_only, preds_prob_rsf_only, import_feat_rsf_only, Y_valid_rsf_only, preds_val_prob_rsf_only

# %% [markdown]
# # Main code

# %%
test_auc_rsf_only, Y_test_rsf_only, X_test_rsf_only, clf_rsf_only, preds_prob_rsf_only, import_feat_rsf_only, Y_valid_rsf_only, preds_val_prob_rsf_only = hyperparametertuning_CV (train_data, test_data, target, unused_feat, Num_FOLDS, Num_feat)
# Out:
# done preprocessing
# rsf mri only
# -------------------------------Training Begining-------------------------------
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=486.0), HTML(value='')))
# Device used : cuda
#
# Early stopping occured at epoch 50 with best_epoch = 30 and best_valid_auc = 0.81279
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.812789 Test AUC: 0.729% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 69 with best_epoch = 49 and best_valid_auc = 0.7932
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.793199 Test AUC: 0.718% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 52 with best_epoch = 32 and best_valid_auc = 0.74143
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.741429 Test AUC: 0.725% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 68 with best_epoch = 48 and best_valid_auc = 0.79811
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.798110 Test AUC: 0.708% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 62 with best_epoch = 42 and best_valid_auc = 0.7899
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.789902 Test AUC: 0.706% Test ACC: 0.505%
# =====parameter별 valid, test score=====
# Validation 평균: 0.787086 Test AUC 평균: 0.717132 Test ACC 평균: 0.502208
# Find new maximum AUC!!
# Device used : cuda
#
# Early stopping occured at epoch 44 with best_epoch = 24 and best_valid_auc = 0.80942
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.809425 Test AUC: 0.699% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 57 with best_epoch = 37 and best_valid_auc = 0.79426
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.794259 Test AUC: 0.728% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 58 with best_epoch = 38 and best_valid_auc = 0.75458
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.754578 Test AUC: 0.724% Test ACC: 0.505%
# Device used : cuda
#
# Early stopping occured at epoch 61 with best_epoch = 41 and best_valid_auc = 0.79723
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.797227 Test AUC: 0.717% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 52 with best_epoch = 32 and best_valid_auc = 0.78306
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.783063 Test AUC: 0.710% Test ACC: 0.502%
# =====parameter별 valid, test score=====
# Validation 평균: 0.787711 Test AUC 평균: 0.715644 Test ACC 평균: 0.502208
# Device used : cuda
#
# Early stopping occured at epoch 50 with best_epoch = 30 and best_valid_auc = 0.81695
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.816953 Test AUC: 0.728% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 67 with best_epoch = 47 and best_valid_auc = 0.8006
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.800602 Test AUC: 0.735% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 102 with best_epoch = 82 and best_valid_auc = 0.75346
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.753456 Test AUC: 0.718% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 99 with best_epoch = 79 and best_valid_auc = 0.79965
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.799649 Test AUC: 0.706% Test ACC: 0.511%
# Device used : cuda
#
# Early stopping occured at epoch 45 with best_epoch = 25 and best_valid_auc = 0.78258
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.782584 Test AUC: 0.723% Test ACC: 0.502%
# =====parameter별 valid, test score=====
# Validation 평균: 0.790649 Test AUC 평균: 0.721981 Test ACC 평균: 0.503470
# Find new maximum AUC!!
# Device used : cuda
#
# Early stopping occured at epoch 39 with best_epoch = 19 and best_valid_auc = 0.79874
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.798738 Test AUC: 0.712% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 49 with best_epoch = 29 and best_valid_auc = 0.79477
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.794765 Test AUC: 0.740% Test ACC: 0.505%
# Device used : cuda
#
# Early stopping occured at epoch 56 with best_epoch = 36 and best_valid_auc = 0.74337
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.743373 Test AUC: 0.729% Test ACC: 0.508%
# Device used : cuda
#
# Early stopping occured at epoch 77 with best_epoch = 57 and best_valid_auc = 0.79516
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.795158 Test AUC: 0.688% Test ACC: 0.517%
# Device used : cuda
#
# Early stopping occured at epoch 54 with best_epoch = 34 and best_valid_auc = 0.78725
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.787251 Test AUC: 0.726% Test ACC: 0.511%
# =====parameter별 valid, test score=====
# Validation 평균: 0.783857 Test AUC 평균: 0.719107 Test ACC 평균: 0.508517
# Device used : cuda
#
# Early stopping occured at epoch 60 with best_epoch = 40 and best_valid_auc = 0.80544
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.805436 Test AUC: 0.714% Test ACC: 0.505%
# Device used : cuda
#
# Early stopping occured at epoch 50 with best_epoch = 30 and best_valid_auc = 0.7951
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.795100 Test AUC: 0.732% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 80 with best_epoch = 60 and best_valid_auc = 0.75542
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.755416 Test AUC: 0.722% Test ACC: 0.517%
# Device used : cuda
#
# Early stopping occured at epoch 70 with best_epoch = 50 and best_valid_auc = 0.80125
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.801250 Test AUC: 0.722% Test ACC: 0.521%
# Device used : cuda
#
# Early stopping occured at epoch 45 with best_epoch = 25 and best_valid_auc = 0.77719
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.777192 Test AUC: 0.715% Test ACC: 0.502%
# =====parameter별 valid, test score=====
# Validation 평균: 0.786879 Test AUC 평균: 0.721025 Test ACC 평균: 0.509148
# Device used : cuda
#
# Early stopping occured at epoch 50 with best_epoch = 30 and best_valid_auc = 0.81732
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.817318 Test AUC: 0.726% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 46 with best_epoch = 26 and best_valid_auc = 0.79138
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.791384 Test AUC: 0.727% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 75 with best_epoch = 55 and best_valid_auc = 0.74986
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.749862 Test AUC: 0.694% Test ACC: 0.521%
# Device used : cuda
#
# Early stopping occured at epoch 91 with best_epoch = 71 and best_valid_auc = 0.80165
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.801652 Test AUC: 0.718% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 45 with best_epoch = 25 and best_valid_auc = 0.78258
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.782584 Test AUC: 0.723% Test ACC: 0.502%
# =====parameter별 valid, test score=====
# Validation 평균: 0.788560 Test AUC 평균: 0.717578 Test ACC 평균: 0.505363
# Device used : cuda
#
# Early stopping occured at epoch 54 with best_epoch = 34 and best_valid_auc = 0.80585
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.805847 Test AUC: 0.725% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 58 with best_epoch = 38 and best_valid_auc = 0.80106
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.801060 Test AUC: 0.727% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 65 with best_epoch = 45 and best_valid_auc = 0.75037
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.750366 Test AUC: 0.717% Test ACC: 0.514%
# Device used : cuda
#
# Early stopping occured at epoch 53 with best_epoch = 33 and best_valid_auc = 0.78846
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.788465 Test AUC: 0.717% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 69 with best_epoch = 49 and best_valid_auc = 0.79362
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.793618 Test AUC: 0.692% Test ACC: 0.511%
# =====parameter별 valid, test score=====
# Validation 평균: 0.787871 Test AUC 평균: 0.715580 Test ACC 평균: 0.505994
# Device used : cuda
#
# Early stopping occured at epoch 52 with best_epoch = 32 and best_valid_auc = 0.80983
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.809828 Test AUC: 0.738% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 48 with best_epoch = 28 and best_valid_auc = 0.7987
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.798701 Test AUC: 0.726% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 76 with best_epoch = 56 and best_valid_auc = 0.76068
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.760677 Test AUC: 0.717% Test ACC: 0.511%
# Device used : cuda
#
# Early stopping occured at epoch 86 with best_epoch = 66 and best_valid_auc = 0.80057
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.800570 Test AUC: 0.701% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 64 with best_epoch = 44 and best_valid_auc = 0.79002
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.790016 Test AUC: 0.716% Test ACC: 0.508%
# =====parameter별 valid, test score=====
# Validation 평균: 0.791958 Test AUC 평균: 0.719489 Test ACC 평균: 0.504732
# Device used : cuda
#
# Early stopping occured at epoch 50 with best_epoch = 30 and best_valid_auc = 0.81428
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.814281 Test AUC: 0.722% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 57 with best_epoch = 37 and best_valid_auc = 0.7933
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.793304 Test AUC: 0.729% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 58 with best_epoch = 38 and best_valid_auc = 0.737
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.736997 Test AUC: 0.725% Test ACC: 0.505%
# Device used : cuda
#
# Early stopping occured at epoch 79 with best_epoch = 59 and best_valid_auc = 0.79258
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.792580 Test AUC: 0.721% Test ACC: 0.514%
# Device used : cuda
#
# Early stopping occured at epoch 45 with best_epoch = 25 and best_valid_auc = 0.78258
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.782584 Test AUC: 0.723% Test ACC: 0.502%
# =====parameter별 valid, test score=====
# Validation 평균: 0.783949 Test AUC 평균: 0.724146 Test ACC 평균: 0.504732
# Find new maximum AUC!!
# Device used : cuda
#
# Early stopping occured at epoch 72 with best_epoch = 52 and best_valid_auc = 0.79033
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.790335 Test AUC: 0.715% Test ACC: 0.505%
# Device used : cuda
#
# Early stopping occured at epoch 51 with best_epoch = 31 and best_valid_auc = 0.78902
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.789024 Test AUC: 0.704% Test ACC: 0.508%
# Device used : cuda
#
# Early stopping occured at epoch 88 with best_epoch = 68 and best_valid_auc = 0.73331
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.733306 Test AUC: 0.694% Test ACC: 0.555%
# Device used : cuda
#
# Early stopping occured at epoch 77 with best_epoch = 57 and best_valid_auc = 0.78506
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.785063 Test AUC: 0.716% Test ACC: 0.530%
# Device used : cuda
#
# Early stopping occured at epoch 76 with best_epoch = 56 and best_valid_auc = 0.78136
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.781356 Test AUC: 0.713% Test ACC: 0.508%
# =====parameter별 valid, test score=====
# Validation 평균: 0.775817 Test AUC 평균: 0.708208 Test ACC 평균: 0.521136
# Device used : cuda
#
# Early stopping occured at epoch 68 with best_epoch = 48 and best_valid_auc = 0.78705
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.787054 Test AUC: 0.722% Test ACC: 0.508%
# Device used : cuda
#
# Early stopping occured at epoch 56 with best_epoch = 36 and best_valid_auc = 0.78626
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.786264 Test AUC: 0.707% Test ACC: 0.505%
# Device used : cuda
#
# Early stopping occured at epoch 85 with best_epoch = 65 and best_valid_auc = 0.72667
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.726670 Test AUC: 0.692% Test ACC: 0.527%
# Device used : cuda
#
# Early stopping occured at epoch 88 with best_epoch = 68 and best_valid_auc = 0.76553
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.765534 Test AUC: 0.702% Test ACC: 0.524%
# Device used : cuda
#
# Early stopping occured at epoch 33 with best_epoch = 13 and best_valid_auc = 0.76648
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.766483 Test AUC: 0.687% Test ACC: 0.502%
# =====parameter별 valid, test score=====
# Validation 평균: 0.766401 Test AUC 평균: 0.701923 Test ACC 평균: 0.512934
# Device used : cuda
#
# Early stopping occured at epoch 64 with best_epoch = 44 and best_valid_auc = 0.7845
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.784504 Test AUC: 0.701% Test ACC: 0.505%
# Device used : cuda
#
# Early stopping occured at epoch 70 with best_epoch = 50 and best_valid_auc = 0.7799
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.779902 Test AUC: 0.728% Test ACC: 0.514%
# Device used : cuda
#
# Early stopping occured at epoch 68 with best_epoch = 48 and best_valid_auc = 0.7306
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.730598 Test AUC: 0.708% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 66 with best_epoch = 46 and best_valid_auc = 0.75098
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.750976 Test AUC: 0.731% Test ACC: 0.508%
# Device used : cuda
#
# Early stopping occured at epoch 33 with best_epoch = 13 and best_valid_auc = 0.76648
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.766483 Test AUC: 0.687% Test ACC: 0.502%
# =====parameter별 valid, test score=====
# Validation 평균: 0.762493 Test AUC 평균: 0.711002 Test ACC 평균: 0.505994
# Device used : cuda
#
# Early stopping occured at epoch 58 with best_epoch = 38 and best_valid_auc = 0.76547
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.765467 Test AUC: 0.664% Test ACC: 0.511%
# Device used : cuda
#
# Early stopping occured at epoch 75 with best_epoch = 55 and best_valid_auc = 0.77634
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.776339 Test AUC: 0.715% Test ACC: 0.498%
# Device used : cuda
#
# Early stopping occured at epoch 60 with best_epoch = 40 and best_valid_auc = 0.7447
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.744698 Test AUC: 0.711% Test ACC: 0.524%
# Device used : cuda
#
# Early stopping occured at epoch 67 with best_epoch = 47 and best_valid_auc = 0.76953
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.769525 Test AUC: 0.711% Test ACC: 0.521%
# Device used : cuda
#
# Early stopping occured at epoch 63 with best_epoch = 43 and best_valid_auc = 0.77481
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.774810 Test AUC: 0.719% Test ACC: 0.502%
# =====parameter별 valid, test score=====
# Validation 평균: 0.766168 Test AUC 평균: 0.703821 Test ACC 평균: 0.511041
# Device used : cuda
#
# Early stopping occured at epoch 73 with best_epoch = 53 and best_valid_auc = 0.78406
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.784063 Test AUC: 0.679% Test ACC: 0.511%
# Device used : cuda
#
# Early stopping occured at epoch 82 with best_epoch = 62 and best_valid_auc = 0.81525
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.815246 Test AUC: 0.716% Test ACC: 0.505%
# Device used : cuda
#
# Early stopping occured at epoch 69 with best_epoch = 49 and best_valid_auc = 0.7312
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.731200 Test AUC: 0.718% Test ACC: 0.527%
# Device used : cuda
#
# Early stopping occured at epoch 70 with best_epoch = 50 and best_valid_auc = 0.75049
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.750492 Test AUC: 0.700% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 33 with best_epoch = 13 and best_valid_auc = 0.76648
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.766483 Test AUC: 0.687% Test ACC: 0.502%
# =====parameter별 valid, test score=====
# Validation 평균: 0.769497 Test AUC 평균: 0.700040 Test ACC 평균: 0.509148
# Device used : cuda
#
# Early stopping occured at epoch 99 with best_epoch = 79 and best_valid_auc = 0.79561
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.795610 Test AUC: 0.700% Test ACC: 0.514%
# Device used : cuda
#
# Early stopping occured at epoch 69 with best_epoch = 49 and best_valid_auc = 0.78774
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.787744 Test AUC: 0.714% Test ACC: 0.505%
# Device used : cuda
#
# Early stopping occured at epoch 61 with best_epoch = 41 and best_valid_auc = 0.72901
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.729012 Test AUC: 0.721% Test ACC: 0.511%
# Device used : cuda
#
# Early stopping occured at epoch 94 with best_epoch = 74 and best_valid_auc = 0.77746
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.777460 Test AUC: 0.678% Test ACC: 0.527%
# Device used : cuda
#
# Early stopping occured at epoch 33 with best_epoch = 13 and best_valid_auc = 0.76648
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.766483 Test AUC: 0.687% Test ACC: 0.502%
# =====parameter별 valid, test score=====
# Validation 평균: 0.771262 Test AUC 평균: 0.699928 Test ACC 평균: 0.511672
# Device used : cuda
#
# Early stopping occured at epoch 51 with best_epoch = 31 and best_valid_auc = 0.7789
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.778902 Test AUC: 0.701% Test ACC: 0.505%
# Device used : cuda
#
# Early stopping occured at epoch 74 with best_epoch = 54 and best_valid_auc = 0.79019
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.790190 Test AUC: 0.685% Test ACC: 0.514%
# Device used : cuda
#
# Early stopping occured at epoch 63 with best_epoch = 43 and best_valid_auc = 0.73331
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.733314 Test AUC: 0.714% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 106 with best_epoch = 86 and best_valid_auc = 0.77195
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.771954 Test AUC: 0.704% Test ACC: 0.514%
# Device used : cuda
#
# Early stopping occured at epoch 47 with best_epoch = 27 and best_valid_auc = 0.77703
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.777030 Test AUC: 0.703% Test ACC: 0.502%
# =====parameter별 valid, test score=====
# Validation 평균: 0.770278 Test AUC 평균: 0.701330 Test ACC 평균: 0.507256
# Device used : cuda
#
# Early stopping occured at epoch 57 with best_epoch = 37 and best_valid_auc = 0.78713
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.787130 Test AUC: 0.694% Test ACC: 0.508%
# Device used : cuda
#
# Early stopping occured at epoch 54 with best_epoch = 34 and best_valid_auc = 0.77388
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.773884 Test AUC: 0.715% Test ACC: 0.511%
# Device used : cuda
#
# Early stopping occured at epoch 70 with best_epoch = 50 and best_valid_auc = 0.73986
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.739860 Test AUC: 0.728% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 93 with best_epoch = 73 and best_valid_auc = 0.76718
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.767182 Test AUC: 0.702% Test ACC: 0.521%
# Device used : cuda
#
# Early stopping occured at epoch 33 with best_epoch = 13 and best_valid_auc = 0.76648
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.766483 Test AUC: 0.687% Test ACC: 0.502%
# =====parameter별 valid, test score=====
# Validation 평균: 0.766908 Test AUC 평균: 0.705167 Test ACC 평균: 0.508517
# Device used : cuda
#
# Early stopping occured at epoch 49 with best_epoch = 29 and best_valid_auc = 0.76703
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.767027 Test AUC: 0.699% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 62 with best_epoch = 42 and best_valid_auc = 0.77889
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.778889 Test AUC: 0.719% Test ACC: 0.524%
# Device used : cuda
#
# Early stopping occured at epoch 97 with best_epoch = 77 and best_valid_auc = 0.72835
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.728345 Test AUC: 0.694% Test ACC: 0.521%
# Device used : cuda
#
# Early stopping occured at epoch 77 with best_epoch = 57 and best_valid_auc = 0.75576
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.755756 Test AUC: 0.711% Test ACC: 0.521%
# Device used : cuda
#
# Early stopping occured at epoch 33 with best_epoch = 13 and best_valid_auc = 0.76648
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.766483 Test AUC: 0.687% Test ACC: 0.502%
# =====parameter별 valid, test score=====
# Validation 평균: 0.759300 Test AUC 평균: 0.702054 Test ACC 평균: 0.513565
# Device used : cuda
#
# Early stopping occured at epoch 34 with best_epoch = 14 and best_valid_auc = 0.79681
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.796812 Test AUC: 0.714% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 85 with best_epoch = 65 and best_valid_auc = 0.78832
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.788317 Test AUC: 0.696% Test ACC: 0.508%
# Device used : cuda
#
# Early stopping occured at epoch 77 with best_epoch = 57 and best_valid_auc = 0.7283
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.728305 Test AUC: 0.706% Test ACC: 0.514%
# Device used : cuda
#
# Early stopping occured at epoch 29 with best_epoch = 9 and best_valid_auc = 0.72513
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.725133 Test AUC: 0.664% Test ACC: 0.498%
# Device used : cuda
#
# Early stopping occured at epoch 51 with best_epoch = 31 and best_valid_auc = 0.76622
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.766223 Test AUC: 0.698% Test ACC: 0.505%
# =====parameter별 valid, test score=====
# Validation 평균: 0.760958 Test AUC 평균: 0.695486 Test ACC 평균: 0.505363
# Device used : cuda
#
# Early stopping occured at epoch 33 with best_epoch = 13 and best_valid_auc = 0.80589
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.805893 Test AUC: 0.708% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 117 with best_epoch = 97 and best_valid_auc = 0.79034
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.790342 Test AUC: 0.696% Test ACC: 0.511%
# Device used : cuda
#
# Early stopping occured at epoch 38 with best_epoch = 18 and best_valid_auc = 0.70986
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.709862 Test AUC: 0.721% Test ACC: 0.505%
# Device used : cuda
#
# Early stopping occured at epoch 29 with best_epoch = 9 and best_valid_auc = 0.72513
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.725133 Test AUC: 0.664% Test ACC: 0.498%
# Device used : cuda
#
# Early stopping occured at epoch 54 with best_epoch = 34 and best_valid_auc = 0.76131
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.761311 Test AUC: 0.710% Test ACC: 0.508%
# =====parameter별 valid, test score=====
# Validation 평균: 0.758508 Test AUC 평균: 0.699865 Test ACC 평균: 0.504732
# Device used : cuda
#
# Early stopping occured at epoch 33 with best_epoch = 13 and best_valid_auc = 0.80589
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.805893 Test AUC: 0.708% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 73 with best_epoch = 53 and best_valid_auc = 0.75304
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.753035 Test AUC: 0.709% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 38 with best_epoch = 18 and best_valid_auc = 0.70986
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.709862 Test AUC: 0.721% Test ACC: 0.505%
# Device used : cuda
#
# Early stopping occured at epoch 29 with best_epoch = 9 and best_valid_auc = 0.72513
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.725133 Test AUC: 0.664% Test ACC: 0.498%
# Device used : cuda
#
# Early stopping occured at epoch 47 with best_epoch = 27 and best_valid_auc = 0.76349
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.763490 Test AUC: 0.719% Test ACC: 0.514%
# =====parameter별 valid, test score=====
# Validation 평균: 0.751483 Test AUC 평균: 0.704299 Test ACC 평균: 0.504101
# Device used : cuda
#
# Early stopping occured at epoch 52 with best_epoch = 32 and best_valid_auc = 0.80706
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.807058 Test AUC: 0.697% Test ACC: 0.505%
# Device used : cuda
#
# Early stopping occured at epoch 101 with best_epoch = 81 and best_valid_auc = 0.77019
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.770192 Test AUC: 0.677% Test ACC: 0.511%
# Device used : cuda
#
# Early stopping occured at epoch 61 with best_epoch = 41 and best_valid_auc = 0.71806
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.718059 Test AUC: 0.705% Test ACC: 0.508%
# Device used : cuda
#
# Early stopping occured at epoch 29 with best_epoch = 9 and best_valid_auc = 0.72513
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.725133 Test AUC: 0.664% Test ACC: 0.498%
# Device used : cuda
#
# Early stopping occured at epoch 38 with best_epoch = 18 and best_valid_auc = 0.76417
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.764173 Test AUC: 0.696% Test ACC: 0.505%
# =====parameter별 valid, test score=====
# Validation 평균: 0.756923 Test AUC 평균: 0.687561 Test ACC 평균: 0.505363
# Device used : cuda
#
# Early stopping occured at epoch 33 with best_epoch = 13 and best_valid_auc = 0.80589
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.805893 Test AUC: 0.708% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 75 with best_epoch = 55 and best_valid_auc = 0.76491
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.764914 Test AUC: 0.681% Test ACC: 0.511%
# Device used : cuda
#
# Early stopping occured at epoch 63 with best_epoch = 43 and best_valid_auc = 0.71655
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.716546 Test AUC: 0.709% Test ACC: 0.511%
# Device used : cuda
#
# Early stopping occured at epoch 108 with best_epoch = 88 and best_valid_auc = 0.77643
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.776429 Test AUC: 0.662% Test ACC: 0.508%
# Device used : cuda
#
# Early stopping occured at epoch 36 with best_epoch = 16 and best_valid_auc = 0.76025
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.760254 Test AUC: 0.670% Test ACC: 0.502%
# =====parameter별 valid, test score=====
# Validation 평균: 0.764807 Test AUC 평균: 0.686004 Test ACC 평균: 0.506625
# Device used : cuda
#
# Early stopping occured at epoch 33 with best_epoch = 13 and best_valid_auc = 0.80589
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.805893 Test AUC: 0.708% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 65 with best_epoch = 45 and best_valid_auc = 0.75465
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.754654 Test AUC: 0.705% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 65 with best_epoch = 45 and best_valid_auc = 0.71291
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.712911 Test AUC: 0.708% Test ACC: 0.508%
# Device used : cuda
#
# Early stopping occured at epoch 29 with best_epoch = 9 and best_valid_auc = 0.72513
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.725133 Test AUC: 0.664% Test ACC: 0.498%
# Device used : cuda
#
# Early stopping occured at epoch 47 with best_epoch = 27 and best_valid_auc = 0.76349
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.763490 Test AUC: 0.719% Test ACC: 0.514%
# =====parameter별 valid, test score=====
# Validation 평균: 0.752416 Test AUC 평균: 0.700828 Test ACC 평균: 0.504732
# Device used : cuda
#
# Early stopping occured at epoch 51 with best_epoch = 31 and best_valid_auc = 0.80158
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.801585 Test AUC: 0.703% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 42 with best_epoch = 22 and best_valid_auc = 0.74775
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.747748 Test AUC: 0.677% Test ACC: 0.511%
# Device used : cuda
#
# Early stopping occured at epoch 35 with best_epoch = 15 and best_valid_auc = 0.7085
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.708504 Test AUC: 0.696% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 87 with best_epoch = 67 and best_valid_auc = 0.75776
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.757763 Test AUC: 0.681% Test ACC: 0.508%
# Device used : cuda
#
# Early stopping occured at epoch 25 with best_epoch = 5 and best_valid_auc = 0.7503
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.750301 Test AUC: 0.689% Test ACC: 0.502%
# =====parameter별 valid, test score=====
# Validation 평균: 0.753180 Test AUC 평균: 0.689213 Test ACC 평균: 0.504732
# Device used : cuda
#
# Early stopping occured at epoch 33 with best_epoch = 13 and best_valid_auc = 0.80589
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.805893 Test AUC: 0.708% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 119 with best_epoch = 99 and best_valid_auc = 0.76945
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.769446 Test AUC: 0.686% Test ACC: 0.517%
# Device used : cuda
#
# Early stopping occured at epoch 38 with best_epoch = 18 and best_valid_auc = 0.70986
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.709862 Test AUC: 0.721% Test ACC: 0.505%
# Device used : cuda
#
# Early stopping occured at epoch 112 with best_epoch = 92 and best_valid_auc = 0.75311
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.753108 Test AUC: 0.706% Test ACC: 0.514%
# Device used : cuda
#
# Early stopping occured at epoch 73 with best_epoch = 53 and best_valid_auc = 0.76388
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.763881 Test AUC: 0.708% Test ACC: 0.514%
# =====parameter별 valid, test score=====
# Validation 평균: 0.760438 Test AUC 평균: 0.705597 Test ACC 평균: 0.510410
# Device used : cuda
#
# Early stopping occured at epoch 33 with best_epoch = 13 and best_valid_auc = 0.80589
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.805893 Test AUC: 0.708% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 56 with best_epoch = 36 and best_valid_auc = 0.75171
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.751712 Test AUC: 0.696% Test ACC: 0.508%
# Device used : cuda
#
# Early stopping occured at epoch 38 with best_epoch = 18 and best_valid_auc = 0.70986
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.709862 Test AUC: 0.721% Test ACC: 0.505%
# Device used : cuda
#
# Early stopping occured at epoch 29 with best_epoch = 9 and best_valid_auc = 0.72513
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.725133 Test AUC: 0.664% Test ACC: 0.498%
# Device used : cuda
#
# Early stopping occured at epoch 47 with best_epoch = 27 and best_valid_auc = 0.76349
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.763490 Test AUC: 0.719% Test ACC: 0.514%
# =====parameter별 valid, test score=====
# Validation 평균: 0.751218 Test AUC 평균: 0.701664 Test ACC 평균: 0.505363
# Device used : cuda
#
# Early stopping occured at epoch 50 with best_epoch = 30 and best_valid_auc = 0.80893
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.808930 Test AUC: 0.723% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 57 with best_epoch = 37 and best_valid_auc = 0.80315
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.803152 Test AUC: 0.721% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 95 with best_epoch = 75 and best_valid_auc = 0.75234
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.752342 Test AUC: 0.718% Test ACC: 0.527%
# Device used : cuda
#
# Early stopping occured at epoch 71 with best_epoch = 51 and best_valid_auc = 0.78251
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.782513 Test AUC: 0.715% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 32 with best_epoch = 12 and best_valid_auc = 0.7675
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.767499 Test AUC: 0.696% Test ACC: 0.505%
# =====parameter별 valid, test score=====
# Validation 평균: 0.782887 Test AUC 평균: 0.714664 Test ACC 평균: 0.507256
# Device used : cuda
#
# Early stopping occured at epoch 60 with best_epoch = 40 and best_valid_auc = 0.80595
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.805946 Test AUC: 0.724% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 64 with best_epoch = 44 and best_valid_auc = 0.79821
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.798214 Test AUC: 0.718% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 74 with best_epoch = 54 and best_valid_auc = 0.73779
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.737794 Test AUC: 0.731% Test ACC: 0.508%
# Device used : cuda
#
# Early stopping occured at epoch 55 with best_epoch = 35 and best_valid_auc = 0.77293
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.772930 Test AUC: 0.731% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 47 with best_epoch = 27 and best_valid_auc = 0.77475
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.774753 Test AUC: 0.712% Test ACC: 0.502%
# =====parameter별 valid, test score=====
# Validation 평균: 0.777927 Test AUC 평균: 0.723278 Test ACC 평균: 0.502839
# Device used : cuda
#
# Early stopping occured at epoch 71 with best_epoch = 51 and best_valid_auc = 0.81016
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.810156 Test AUC: 0.731% Test ACC: 0.505%
# Device used : cuda
#
# Early stopping occured at epoch 74 with best_epoch = 54 and best_valid_auc = 0.78721
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.787209 Test AUC: 0.734% Test ACC: 0.511%
# Device used : cuda
#
# Early stopping occured at epoch 70 with best_epoch = 50 and best_valid_auc = 0.75142
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.751423 Test AUC: 0.732% Test ACC: 0.508%
# Device used : cuda
#
# Early stopping occured at epoch 71 with best_epoch = 51 and best_valid_auc = 0.78829
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.788293 Test AUC: 0.733% Test ACC: 0.505%
# Device used : cuda
#
# Early stopping occured at epoch 75 with best_epoch = 55 and best_valid_auc = 0.78514
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.785137 Test AUC: 0.724% Test ACC: 0.511%
# =====parameter별 valid, test score=====
# Validation 평균: 0.784444 Test AUC 평균: 0.730889 Test ACC 평균: 0.507886
# Find new maximum AUC!!
# Device used : cuda
#
# Early stopping occured at epoch 55 with best_epoch = 35 and best_valid_auc = 0.81676
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.816763 Test AUC: 0.725% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 76 with best_epoch = 56 and best_valid_auc = 0.80304
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.803038 Test AUC: 0.701% Test ACC: 0.514%
# Device used : cuda
#
# Early stopping occured at epoch 45 with best_epoch = 25 and best_valid_auc = 0.7371
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.737103 Test AUC: 0.721% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 74 with best_epoch = 54 and best_valid_auc = 0.7786
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.778600 Test AUC: 0.707% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 39 with best_epoch = 19 and best_valid_auc = 0.76739
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.767394 Test AUC: 0.713% Test ACC: 0.502%
# =====parameter별 valid, test score=====
# Validation 평균: 0.780580 Test AUC 평균: 0.713462 Test ACC 평균: 0.504101
# Device used : cuda
#
# Early stopping occured at epoch 58 with best_epoch = 38 and best_valid_auc = 0.81283
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.812835 Test AUC: 0.717% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 62 with best_epoch = 42 and best_valid_auc = 0.79273
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.792731 Test AUC: 0.725% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 97 with best_epoch = 77 and best_valid_auc = 0.75462
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.754619 Test AUC: 0.710% Test ACC: 0.530%
# Device used : cuda
#
# Early stopping occured at epoch 86 with best_epoch = 66 and best_valid_auc = 0.79128
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.791276 Test AUC: 0.700% Test ACC: 0.514%
# Device used : cuda
#
# Early stopping occured at epoch 67 with best_epoch = 47 and best_valid_auc = 0.78258
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.782584 Test AUC: 0.725% Test ACC: 0.505%
# =====parameter별 valid, test score=====
# Validation 평균: 0.786809 Test AUC 평균: 0.715469 Test ACC 평균: 0.510410
# Device used : cuda
#
# Early stopping occured at epoch 59 with best_epoch = 39 and best_valid_auc = 0.81137
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.811373 Test AUC: 0.727% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 61 with best_epoch = 41 and best_valid_auc = 0.7951
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.795100 Test AUC: 0.725% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 48 with best_epoch = 28 and best_valid_auc = 0.73315
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.733147 Test AUC: 0.725% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 84 with best_epoch = 64 and best_valid_auc = 0.79202
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.792018 Test AUC: 0.730% Test ACC: 0.517%
# Device used : cuda
#
# Early stopping occured at epoch 73 with best_epoch = 53 and best_valid_auc = 0.7967
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.796700 Test AUC: 0.723% Test ACC: 0.502%
# =====parameter별 valid, test score=====
# Validation 평균: 0.785668 Test AUC 평균: 0.725969 Test ACC 평균: 0.504732
# Device used : cuda
#
# Early stopping occured at epoch 59 with best_epoch = 39 and best_valid_auc = 0.81507
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.815073 Test AUC: 0.731% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 69 with best_epoch = 49 and best_valid_auc = 0.79657
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.796571 Test AUC: 0.722% Test ACC: 0.505%
# Device used : cuda
#
# Early stopping occured at epoch 41 with best_epoch = 21 and best_valid_auc = 0.73204
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.732037 Test AUC: 0.724% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 86 with best_epoch = 66 and best_valid_auc = 0.78136
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.781357 Test AUC: 0.709% Test ACC: 0.511%
# Device used : cuda
#
# Early stopping occured at epoch 72 with best_epoch = 52 and best_valid_auc = 0.78759
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.787593 Test AUC: 0.710% Test ACC: 0.511%
# =====parameter별 valid, test score=====
# Validation 평균: 0.782526 Test AUC 평균: 0.719449 Test ACC 평균: 0.505994
# Device used : cuda
#
# Early stopping occured at epoch 58 with best_epoch = 38 and best_valid_auc = 0.81193
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.811929 Test AUC: 0.716% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 71 with best_epoch = 51 and best_valid_auc = 0.79174
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.791737 Test AUC: 0.679% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 99 with best_epoch = 79 and best_valid_auc = 0.75306
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.753062 Test AUC: 0.691% Test ACC: 0.514%
# Device used : cuda
#
# Early stopping occured at epoch 87 with best_epoch = 67 and best_valid_auc = 0.792
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.792002 Test AUC: 0.703% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 45 with best_epoch = 25 and best_valid_auc = 0.77009
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.770093 Test AUC: 0.708% Test ACC: 0.502%
# =====parameter별 valid, test score=====
# Validation 평균: 0.783765 Test AUC 평균: 0.699721 Test ACC 평균: 0.504101
# Device used : cuda
#
# Early stopping occured at epoch 58 with best_epoch = 38 and best_valid_auc = 0.80722
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.807217 Test AUC: 0.717% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 74 with best_epoch = 54 and best_valid_auc = 0.79586
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.795864 Test AUC: 0.723% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 79 with best_epoch = 59 and best_valid_auc = 0.75487
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.754871 Test AUC: 0.756% Test ACC: 0.517%
# Device used : cuda
#
# Early stopping occured at epoch 95 with best_epoch = 75 and best_valid_auc = 0.79977
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.799766 Test AUC: 0.730% Test ACC: 0.527%
# Device used : cuda
#
# Early stopping occured at epoch 78 with best_epoch = 58 and best_valid_auc = 0.78275
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.782746 Test AUC: 0.718% Test ACC: 0.514%
# =====parameter별 valid, test score=====
# Validation 평균: 0.788093 Test AUC 평균: 0.728915 Test ACC 평균: 0.512303
# Device used : cuda
#
# Early stopping occured at epoch 50 with best_epoch = 30 and best_valid_auc = 0.81274
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.812736 Test AUC: 0.728% Test ACC: 0.511%
# Device used : cuda
#
# Early stopping occured at epoch 87 with best_epoch = 67 and best_valid_auc = 0.78831
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.788308 Test AUC: 0.736% Test ACC: 0.505%
# Device used : cuda
#
# Early stopping occured at epoch 47 with best_epoch = 27 and best_valid_auc = 0.72584
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.725841 Test AUC: 0.689% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 61 with best_epoch = 41 and best_valid_auc = 0.752
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.751999 Test AUC: 0.699% Test ACC: 0.498%
# Device used : cuda
#
# Early stopping occured at epoch 46 with best_epoch = 26 and best_valid_auc = 0.76896
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.768963 Test AUC: 0.713% Test ACC: 0.502%
# =====parameter별 valid, test score=====
# Validation 평균: 0.769569 Test AUC 평균: 0.712833 Test ACC 평균: 0.503470
# Device used : cuda
#
# Early stopping occured at epoch 60 with best_epoch = 40 and best_valid_auc = 0.81271
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.812713 Test AUC: 0.717% Test ACC: 0.514%
# Device used : cuda
#
# Early stopping occured at epoch 82 with best_epoch = 62 and best_valid_auc = 0.76444
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.764436 Test AUC: 0.689% Test ACC: 0.521%
# Device used : cuda
#
# Early stopping occured at epoch 39 with best_epoch = 19 and best_valid_auc = 0.73253
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.732525 Test AUC: 0.701% Test ACC: 0.505%
# Device used : cuda
#
# Early stopping occured at epoch 63 with best_epoch = 43 and best_valid_auc = 0.76601
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.766011 Test AUC: 0.699% Test ACC: 0.511%
# Device used : cuda
#
# Early stopping occured at epoch 77 with best_epoch = 57 and best_valid_auc = 0.78133
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.781331 Test AUC: 0.700% Test ACC: 0.517%
# =====parameter별 valid, test score=====
# Validation 평균: 0.771403 Test AUC 평균: 0.701282 Test ACC 평균: 0.513565
# Device used : cuda
#
# Early stopping occured at epoch 50 with best_epoch = 30 and best_valid_auc = 0.79767
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.797672 Test AUC: 0.691% Test ACC: 0.508%
# Device used : cuda
#
# Early stopping occured at epoch 29 with best_epoch = 9 and best_valid_auc = 0.73737
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.737374 Test AUC: 0.661% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 39 with best_epoch = 19 and best_valid_auc = 0.73253
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.732525 Test AUC: 0.701% Test ACC: 0.505%
# Device used : cuda
#
# ...
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.705837 Test AUC: 0.682% Test ACC: 0.498%
# Device used : cuda
#
# Early stopping occured at epoch 144 with best_epoch = 124 and best_valid_auc = 0.74555
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.745548 Test AUC: 0.696% Test ACC: 0.498%
# Device used : cuda
#
# Early stopping occured at epoch 65 with best_epoch = 45 and best_valid_auc = 0.73648
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.736477 Test AUC: 0.676% Test ACC: 0.505%
# =====parameter별 valid, test score=====
# Validation 평균: 0.744395 Test AUC 평균: 0.681769 Test ACC 평균: 0.502208
# Device used : cuda
#
# Early stopping occured at epoch 61 with best_epoch = 41 and best_valid_auc = 0.74591
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.745912 Test AUC: 0.630% Test ACC: 0.505%
# Device used : cuda
#
# Early stopping occured at epoch 143 with best_epoch = 123 and best_valid_auc = 0.75807
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.758074 Test AUC: 0.685% Test ACC: 0.508%
# Device used : cuda
#
# Early stopping occured at epoch 95 with best_epoch = 75 and best_valid_auc = 0.70852
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.708520 Test AUC: 0.667% Test ACC: 0.505%
# Device used : cuda
#
# Early stopping occured at epoch 89 with best_epoch = 69 and best_valid_auc = 0.71982
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.719822 Test AUC: 0.662% Test ACC: 0.498%
# Device used : cuda
#
# Early stopping occured at epoch 153 with best_epoch = 133 and best_valid_auc = 0.7713
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.771305 Test AUC: 0.665% Test ACC: 0.502%
# =====parameter별 valid, test score=====
# Validation 평균: 0.740727 Test AUC 평균: 0.661986 Test ACC 평균: 0.503470
# Device used : cuda
#
# Early stopping occured at epoch 118 with best_epoch = 98 and best_valid_auc = 0.76286
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.762864 Test AUC: 0.680% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 90 with best_epoch = 70 and best_valid_auc = 0.71572
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.715723 Test AUC: 0.624% Test ACC: 0.508%
# Device used : cuda
#
# Early stopping occured at epoch 113 with best_epoch = 93 and best_valid_auc = 0.70117
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.701169 Test AUC: 0.722% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 81 with best_epoch = 61 and best_valid_auc = 0.71971
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.719713 Test AUC: 0.653% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 110 with best_epoch = 90 and best_valid_auc = 0.74232
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.742324 Test AUC: 0.656% Test ACC: 0.502%
# =====parameter별 valid, test score=====
# Validation 평균: 0.728359 Test AUC 평균: 0.667001 Test ACC 평균: 0.502839
# Device used : cuda
#
# Early stopping occured at epoch 129 with best_epoch = 109 and best_valid_auc = 0.77783
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.777829 Test AUC: 0.656% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 121 with best_epoch = 101 and best_valid_auc = 0.76553
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.765535 Test AUC: 0.640% Test ACC: 0.508%
# Device used : cuda
#
# Early stopping occured at epoch 65 with best_epoch = 45 and best_valid_auc = 0.68468
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.684678 Test AUC: 0.642% Test ACC: 0.498%
# Device used : cuda
#
# Early stopping occured at epoch 53 with best_epoch = 33 and best_valid_auc = 0.71004
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.710044 Test AUC: 0.662% Test ACC: 0.498%
# Device used : cuda
#
# Early stopping occured at epoch 144 with best_epoch = 124 and best_valid_auc = 0.76077
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.760766 Test AUC: 0.652% Test ACC: 0.502%
# =====parameter별 valid, test score=====
# Validation 평균: 0.739770 Test AUC 평균: 0.650338 Test ACC 평균: 0.501577
# Device used : cuda
#
# Early stopping occured at epoch 137 with best_epoch = 117 and best_valid_auc = 0.76892
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.768915 Test AUC: 0.654% Test ACC: 0.505%
# Device used : cuda
#
# Early stopping occured at epoch 84 with best_epoch = 64 and best_valid_auc = 0.7473
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.747299 Test AUC: 0.642% Test ACC: 0.505%
# Device used : cuda
#
# Early stopping occured at epoch 53 with best_epoch = 33 and best_valid_auc = 0.66915
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.669147 Test AUC: 0.605% Test ACC: 0.505%
# Device used : cuda
#
# Early stopping occured at epoch 167 with best_epoch = 147 and best_valid_auc = 0.7502
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.750195 Test AUC: 0.665% Test ACC: 0.495%
# Device used : cuda
#
# Early stopping occured at epoch 77 with best_epoch = 57 and best_valid_auc = 0.74602
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.746015 Test AUC: 0.654% Test ACC: 0.505%
# =====parameter별 valid, test score=====
# Validation 평균: 0.736314 Test AUC 평균: 0.643906 Test ACC 평균: 0.502839
# Device used : cuda
#
# Early stopping occured at epoch 34 with best_epoch = 14 and best_valid_auc = 0.54333
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.543326 Test AUC: 0.514% Test ACC: 0.498%
# Device used : cuda
#
# Early stopping occured at epoch 131 with best_epoch = 111 and best_valid_auc = 0.6492
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.649205 Test AUC: 0.615% Test ACC: 0.505%
# Device used : cuda
# Stop training because you reached max_epochs = 200 with best_epoch = 192 and best_valid_auc = 0.70023
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.700234 Test AUC: 0.662% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 88 with best_epoch = 68 and best_valid_auc = 0.67196
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.671962 Test AUC: 0.574% Test ACC: 0.502%
# Device used : cuda
# Stop training because you reached max_epochs = 200 with best_epoch = 192 and best_valid_auc = 0.74686
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.746861 Test AUC: 0.661% Test ACC: 0.498%
# =====parameter별 valid, test score=====
# Validation 평균: 0.662318 Test AUC 평균: 0.605342 Test ACC 평균: 0.500946
# Device used : cuda
#
# Early stopping occured at epoch 80 with best_epoch = 60 and best_valid_auc = 0.61609
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.616087 Test AUC: 0.595% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 186 with best_epoch = 166 and best_valid_auc = 0.73414
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.734136 Test AUC: 0.721% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 181 with best_epoch = 161 and best_valid_auc = 0.69561
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.695607 Test AUC: 0.658% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 87 with best_epoch = 67 and best_valid_auc = 0.67725
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.677249 Test AUC: 0.570% Test ACC: 0.502%
# Device used : cuda
# Stop training because you reached max_epochs = 200 with best_epoch = 198 and best_valid_auc = 0.76456
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.764556 Test AUC: 0.683% Test ACC: 0.502%
# =====parameter별 valid, test score=====
# Validation 평균: 0.697527 Test AUC 평균: 0.645458 Test ACC 평균: 0.501577
# Device used : cuda
#
# Early stopping occured at epoch 51 with best_epoch = 31 and best_valid_auc = 0.56112
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.561122 Test AUC: 0.517% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 71 with best_epoch = 51 and best_valid_auc = 0.59485
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.594851 Test AUC: 0.585% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 114 with best_epoch = 94 and best_valid_auc = 0.67481
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.674815 Test AUC: 0.610% Test ACC: 0.502%
# Device used : cuda
# Stop training because you reached max_epochs = 200 with best_epoch = 196 and best_valid_auc = 0.73925
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.739246 Test AUC: 0.706% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 68 with best_epoch = 48 and best_valid_auc = 0.61624
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.616242 Test AUC: 0.540% Test ACC: 0.502%
# =====parameter별 valid, test score=====
# Validation 평균: 0.637255 Test AUC 평균: 0.591585 Test ACC 평균: 0.501577
# Device used : cuda
#
# Early stopping occured at epoch 52 with best_epoch = 32 and best_valid_auc = 0.56613
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.566131 Test AUC: 0.525% Test ACC: 0.498%
# Device used : cuda
#
# Early stopping occured at epoch 36 with best_epoch = 16 and best_valid_auc = 0.5233
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.523303 Test AUC: 0.542% Test ACC: 0.498%
# Device used : cuda
#
# Early stopping occured at epoch 100 with best_epoch = 80 and best_valid_auc = 0.66782
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.667821 Test AUC: 0.612% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 186 with best_epoch = 166 and best_valid_auc = 0.73422
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.734216 Test AUC: 0.708% Test ACC: 0.502%
# Device used : cuda
# Stop training because you reached max_epochs = 200 with best_epoch = 198 and best_valid_auc = 0.76599
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.765987 Test AUC: 0.709% Test ACC: 0.502%
# =====parameter별 valid, test score=====
# Validation 평균: 0.651492 Test AUC 평균: 0.619433 Test ACC 평균: 0.500315
# Device used : cuda
# Stop training because you reached max_epochs = 200 with best_epoch = 196 and best_valid_auc = 0.78081
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.780812 Test AUC: 0.702% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 170 with best_epoch = 150 and best_valid_auc = 0.75101
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.751015 Test AUC: 0.691% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 107 with best_epoch = 87 and best_valid_auc = 0.66604
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.666041 Test AUC: 0.592% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 82 with best_epoch = 62 and best_valid_auc = 0.67781
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.677812 Test AUC: 0.586% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 169 with best_epoch = 149 and best_valid_auc = 0.75302
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.753017 Test AUC: 0.686% Test ACC: 0.502%
# =====parameter별 valid, test score=====
# Validation 평균: 0.725739 Test AUC 평균: 0.651477 Test ACC 평균: 0.501577
# Device used : cuda
#
# Early stopping occured at epoch 41 with best_epoch = 21 and best_valid_auc = 0.55821
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.558215 Test AUC: 0.522% Test ACC: 0.498%
# Device used : cuda
#
# Early stopping occured at epoch 92 with best_epoch = 72 and best_valid_auc = 0.60966
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.609658 Test AUC: 0.614% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 110 with best_epoch = 90 and best_valid_auc = 0.67477
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.674766 Test AUC: 0.581% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 79 with best_epoch = 59 and best_valid_auc = 0.67202
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.672017 Test AUC: 0.565% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 173 with best_epoch = 153 and best_valid_auc = 0.76334
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.763344 Test AUC: 0.675% Test ACC: 0.502%
# =====parameter별 valid, test score=====
# Validation 평균: 0.655600 Test AUC 평균: 0.591454 Test ACC 평균: 0.500946
# Device used : cuda
#
# Early stopping occured at epoch 182 with best_epoch = 162 and best_valid_auc = 0.63594
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.635938 Test AUC: 0.602% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 41 with best_epoch = 21 and best_valid_auc = 0.53503
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.535034 Test AUC: 0.522% Test ACC: 0.498%
# Device used : cuda
#
# Early stopping occured at epoch 84 with best_epoch = 64 and best_valid_auc = 0.61742
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.617421 Test AUC: 0.539% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 85 with best_epoch = 65 and best_valid_auc = 0.6757
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.675695 Test AUC: 0.552% Test ACC: 0.502%
# Device used : cuda
# Stop training because you reached max_epochs = 200 with best_epoch = 193 and best_valid_auc = 0.67496
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.674961 Test AUC: 0.617% Test ACC: 0.502%
# =====parameter별 valid, test score=====
# Validation 평균: 0.627810 Test AUC 평균: 0.566587 Test ACC 평균: 0.500946
# Device used : cuda
#
# Early stopping occured at epoch 171 with best_epoch = 151 and best_valid_auc = 0.70723
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.707230 Test AUC: 0.625% Test ACC: 0.498%
# Device used : cuda
#
# Early stopping occured at epoch 88 with best_epoch = 68 and best_valid_auc = 0.64492
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.644916 Test AUC: 0.577% Test ACC: 0.498%
# Device used : cuda
#
# Early stopping occured at epoch 113 with best_epoch = 93 and best_valid_auc = 0.67662
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.676620 Test AUC: 0.608% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 63 with best_epoch = 43 and best_valid_auc = 0.66266
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.662660 Test AUC: 0.526% Test ACC: 0.502%
# Device used : cuda
# Stop training because you reached max_epochs = 200 with best_epoch = 194 and best_valid_auc = 0.75276
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.752757 Test AUC: 0.663% Test ACC: 0.502%
# =====parameter별 valid, test score=====
# Validation 평균: 0.688836 Test AUC 평균: 0.599841 Test ACC 평균: 0.500315
# Device used : cuda
#
# Early stopping occured at epoch 41 with best_epoch = 21 and best_valid_auc = 0.55821
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.558215 Test AUC: 0.522% Test ACC: 0.498%
# Device used : cuda

# %% [markdown]
# # Getting results

# %%
valid_auc_all = roc_auc_score (Y_valid_all, preds_val_prob_all[:,1])
valid_auc_pheno = roc_auc_score (Y_valid_pheno, preds_val_prob_pheno[:,1])
valid_auc_mri = roc_auc_score (Y_valid_mri, preds_val_prob_mri[:,1])

def classify (preds_prob_all, Y_test, line):
    y_pred_all = []
    for x in preds_prob_all[:,1]:
        if x > line:
            y_pred_all.append(1)
        else:
            y_pred_all.append(0)
    y_pred_all=np.array(y_pred_all)
    test_acc = accuracy_score(y_pred_all, Y_test)
    #print(test_acc)
    return y_pred_all, test_acc

def find_best_boundary(preds_prob_all,Y_test):
    results =[]
    idx =[]
    for i in  np.arange(0.01, 0.35, 0.01):
   
        idx.append(i)
        _,test_acc =classify(preds_prob_all,Y_test, i)
        results.append(test_acc)

    results
    num_idx=results.index(max(results))
    best_idx =idx[num_idx]
    #print(f'best_classify_boundary {best_idx}')
    y_pred_all,test_acc =classify(preds_prob_all, Y_test, best_idx)
    #print(f'best ACC= {test_acc}')
    return best_idx

def confusion_stuff (Y_test, preds_prob_all):
    best_idx=find_best_boundary(preds_prob_all,Y_test)
    y_pred_all, test_acc =classify (preds_prob_all, Y_test, 0.15)
    TN, FP, FN, TP = confusion_matrix(y_true=Y_test, y_pred = y_pred_all).ravel()
    print(TN,FP)
    print(FN,TP)
    
    sensitivity =TP/(TP+FN)
    specificity =TN/(TN+FP)
    PPV = TP/(TP+FP)
    NPV = TN/(TN+FN)
    Accuracy = test_acc
    return sensitivity, specificity, PPV, NPV, Accuracy

def makeround(sensitivity_all, specificity_all, PPV_all, NPV_all, Accuracy_all):
    lists = sensitivity_all, specificity_all, PPV_all, NPV_all, Accuracy_all
    new_lists=[]
    for list in lists:
        new_list =  round(list*100,2)
        new_lists.append(new_list)
    
    return new_lists[0], new_lists[1], new_lists[2], new_lists[3], new_lists[4]
        
print("<<<<All>>>>")
sensitivity_all, specificity_all, PPV_all, NPV_all, Accuracy_all = confusion_stuff(Y_test_all, preds_prob_all)
sensitivity_all, specificity_all, PPV_all, NPV_all, Accuracy_all = makeround(sensitivity_all, specificity_all, PPV_all, NPV_all, Accuracy_all)
print(f"sensitivity {sensitivity_all}% specificity {sensitivity_all}% PPV {sensitivity_all}% NPV {NPV_all}% Accuracy {Accuracy_all}% Valid_AUC {round(valid_auc_all*100,2)}% Test_AUC {round(test_auc_all*100,2)}% " )

print("<<<<psychosocial>>>>")
sensitivity_pheno, specificity_pheno, PPV_pheno, NPV_pheno, Accuracy_pheno = confusion_stuff(Y_test_pheno, preds_prob_pheno)
sensitivity_pheno, specificity_pheno, PPV_pheno, NPV_pheno, Accuracy_pheno= makeround(sensitivity_pheno, specificity_pheno, PPV_pheno, NPV_pheno, Accuracy_pheno)
print(f"sensitivity {sensitivity_pheno}% specificity {specificity_pheno}% PPV {PPV_pheno}% NPV {NPV_pheno}% Accuracy {Accuracy_pheno}% Valid_AUC {round(valid_auc_pheno*100,2)}% Test_AUC {round(test_auc_pheno*100,2)}%")

print("<<<<MRI>>>>")
sensitivity_mri, specificity_mri, PPV_mri, NPV_mri, Accuracy_mri = confusion_stuff(Y_test_mri, preds_prob_mri)
sensitivity_mri, specificity_mri, PPV_mri, NPV_mri, Accuracy_mri = makeround(sensitivity_mri, specificity_mri, PPV_mri, NPV_mri, Accuracy_mri )
print(f"sensitivity {sensitivity_mri}% specificity {specificity_mri}% PPV {PPV_mri}% NPV {NPV_mri}% Accuracy {Accuracy_mri}% Valid_AUC {round(valid_auc_mri*100,2)}% Test_AUC {round(test_auc_mri*100,2)}%")

# %% [markdown]
# # For drawing ROC curve graph

# %%
def rocvis(true , prob , label ) :
    from sklearn.metrics import roc_curve
    if type(true[0]) == str :
        from sklearn.preprocessing import LabelEncoder
        le = LabelEncoder()
        true = le.fit_transform(true)
    else :
        pass
    fpr, tpr, thresholds = roc_curve(true, prob)
    plt.plot(fpr, tpr, marker='.', label = label  )

# %% [markdown]
# # Draw ROC curve

# %%
fig , ax = plt.subplots(figsize= (20,10))
plt.plot([0, 1], [0, 1], linestyle='--')
rocvis(Y_test_all , preds_prob_all[:,1] , f"Combined:{round(test_auc_all*100, 2)}%")
rocvis(Y_test_pheno , preds_prob_pheno[:,1] , f"psychosocial:{round(test_auc_pheno*100, 2)}%")
rocvis(Y_test_mri , preds_prob_mri[:,1] , f"MRI:{round(test_auc_mri*100, 2)}%")
    #rocvis(caty_Test , catprob[:,1] , "CatBoost")
dataset_name="enbackfMRI"

plt.legend(fontsize = 40)
plt.title(dataset_name, fontsize= 50)
plt.xlabel("FP rate", fontsize =30)
plt.ylabel("TP rate", fontsize =30)
plt.xticks(size = 30)
plt.yticks(size = 30)

plt.tight_layout()
plt.savefig(f'{dataset_name}_ROC.png')

# %% [markdown]
# # For model interpretation. with subjectkey below datas are needed
#
# name_test_all, name_train_all, name_valid_all,
# name_test_pheno, name_train_pheno, name_valid_pheno,
# name_test_mri, name_train_mri, name_valid_mri,
# Y_test_all , preds_prob_all,
# Y_test_pheno , preds_prob_pheno,
# Y_test_mri , preds_prob_mri,
# Y_valid_all, preds_val_prob_all,
# Y_valid_pheno, preds_val_prob_pheno,
# Y_valid_mri, preds_val_prob_mri

# %%
def save_prob_with_true(Y_test,preds_prob, subjectkey, testORvalid, modeltype):
    
    combined_model=pd.DataFrame({f"subjectkey_{testORvalid}_{modeltype}": subjectkey, f"Y_{testORvalid}_{modeltype}":Y_test, f"preds_prob_{testORvalid}_{modeltype}" :preds_prob[:,1]} )
    combined_model.to_csv(f"{dataset_name}_combined_forROC_{modeltype}_{testORvalid}.csv")
    return combined_model

# %%
result_test_all = save_prob_with_true(Y_test_all, preds_prob_all, name_test_all, "test", "all")
result_valid_all = save_prob_with_true(Y_valid_all, preds_val_prob_all, name_valid_all, "valid", "all")

result_test_pheno = save_prob_with_true(Y_test_pheno, preds_prob_pheno, name_test_pheno, "test", "psychosocial")
result_valid_pheno = save_prob_with_true(Y_valid_pheno, preds_val_prob_pheno, name_valid_pheno, "valid", "psychosocial")

result_test_mri = save_prob_with_true(Y_test_mri, preds_prob_mri, name_test_mri, "test", "mri")
result_valid_mri = save_prob_with_true(Y_valid_mri, preds_val_prob_mri, name_valid_mri, "valid", "mri")

# %% [markdown]
# # save feature importance

# %%
import_feat_every=pd.concat([import_feat_all,import_feat_pheno, import_feat_mri])

import_feat_every.to_csv(f"{dataset_name}_features.csv")

import_feat_every

# %% [markdown]
# # Draw AUC per epochs and loss per epochs

# %%
feature_names=["Combined", "psychosocial", "MRI"]
clfs = [clf_all, clf_pheno, clf_mri ]
simple_name = "enbackfMRI"

def error_plot(clf):
    plt.plot(clf.history['train_auc'])
    plt.plot(clf.history['valid_auc'])

for i in range(3):
    error_plot(clfs[i])

plt.legend([f'train_{feature_names[0]}', f'valid_{feature_names[0]}', 
           f'train_{feature_names[1]}', f'valid_{feature_names[1]}',
           f'train_{feature_names[2]}', f'valid_{feature_names[2]}'])
plt.title(f'{simple_name}')
plt.xlabel('epochs')
plt.ylabel('AUC')
plt.tight_layout()

plt.savefig(f'AUC_per_epochs {simple_name}.png')

plt.show()          


feature_names=["combined", "psychosocial", "MRI"]
clfs = [clf_all, clf_pheno, clf_mri ]

def error_plot(clf):
    plt.plot(clf.history['loss'])

for i in range(3):
    error_plot(clfs[i])

plt.legend([f'{feature_names[0]}', 
           f'{feature_names[1]}',
           f'{feature_names[2]}'])
plt.title(f'{simple_name}')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.tight_layout()

plt.savefig(f'loss_per_epochs {simple_name}.png')

plt.show()

# %% [markdown]
# # Model save

# %%
def saveclf(clf,name):
    clf.save_model(f'{simple_name}_{name}')
saveclf(clf_all,"all")
saveclf(clf_pheno,"combined")
saveclf(clf_mri,"mri")
