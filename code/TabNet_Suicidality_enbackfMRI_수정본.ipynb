# %% [markdown]
# # load libraries and data

# %%
from torch import nn
import torch
from torch import tensor 
from torch.autograd import Variable
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from pytorch_tabnet.tab_model import TabNetClassifier, TabNetRegressor
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import KFold
import torch
import itertools
from pytorch_tabnet.tab_model import TabNetClassifier
from sklearn.metrics import roc_auc_score, accuracy_score
from tqdm.notebook import tqdm
from pathlib import Path
import os

# psychosocial + rsfMRI + strurctural MRI + diffusion MRI

train_out = Path('./data/si_ppc_rsf_s_dMRI_train.csv')
test_out =Path('./data/si_ppc_rsf_s_dMRI_test.csv')

train_data= pd.read_csv(train_out)
test_data= pd.read_csv(test_out)

target ='Suicidalideation'
unused_feat = ['subjectkey', 'abcd_site']

# mri feature가 시작하는 column의 index 구하기
# np.where의 결과값이 array에 들어가기 때문에 방금 계산해 넣어놓은 [0]번째 값을 가져온다.
start_rsfmri_index = np.where(test_data.columns.values == "rsfmri_var_cort.destrieux_g.and.s.frontomargin.lh")[0][0]
start_structmri_index = np.where(test_data.columns.values == "lh_bankssts_area._.1")[0][0]
start_diffmri_index = np.where(test_data.columns.values == "con_L.BSTS_L.CACG_count")[0][0]

rsf_mri = list(test_data.columns[start_rsfmri_index:start_structmri_index])
structural_mri = list(test_data.columns[start_structmri_index:start_diffmri_index])
diffusion_mri = list(test_data.columns[start_diffmri_index:])

Num_FOLDS  = 5
# the number of feature that you want to show 
Num_feat = 20

print(len(train_data), len(train_data.columns))
print(len(rsf_mri))
print(len(structural_mri))
print(len(diffusion_mri))
# Out:
# 5510 4750
# 148
# 984
# 3485

# %%
train_data['subjectkey']
#test_data['subjectkey']
# Out:
# 0       NDARINV003RTV85
# 1       NDARINV00BD7VDC
# 2       NDARINV00R4TXET
# 3       NDARINV00U4FTRU
# 4       NDARINV00UMK5VC
#              ...
# 5505    NDARINVZZJ3A7BK
# 5506    NDARINVZZLZCKAY
# 5507    NDARINVZZPKBDAC
# 5508    NDARINVZZZ2ALR6
# 5509    NDARINVZZZNB0XC
# Name: subjectkey, Length: 5510, dtype: object

# %% [markdown]
# # Fine object featrues

# %%
# reset_index(drop=True): index값 초기화 + drop으로 index 열 삭제
train_data_processed = train_data.fillna(0).reset_index(drop=True)

features = [col for col in train_data_processed.columns 
            if col not in unused_feat + [target] + mri and test_data[col].dtypes != 'object']
print(features)
# Out:
# ['race.ethnicity_1', 'race.ethnicity_2', 'race.ethnicity_3', 'race.ethnicity_4', 'race.ethnicity_5', 'sex_1', 'sex_2', 'high.educ_1', 'high.educ_2', 'high.educ_3', 'high.educ_4', 'high.educ_5', 'high.educ_6', 'high.educ_7', 'high.educ_8', 'high.educ_9', 'high.educ_10', 'high.educ_11', 'high.educ_12', 'high.educ_13', 'high.educ_14', 'high.educ_15', 'high.educ_16', 'high.educ_17', 'high.educ_18', 'high.educ_19', 'income_1', 'income_2', 'income_3', 'income_4', 'income_5', 'income_6', 'income_7', 'income_8', 'income_9', 'income_10', 'married_1', 'married_2', 'married_3', 'married_4', 'married_5', 'married_6', 'fes_q1_1', 'fes_q1_2', 'fes_q2_1', 'fes_q2_2', 'fes_q3_1', 'fes_q3_2', 'fes_q4_1', 'fes_q4_2', 'fes_q5_1', 'fes_q5_2', 'fes_q6_1', 'fes_q6_2', 'fes_q7_1', 'fes_q7_2', 'fes_q8_1', 'fes_q8_2', 'fes_q9_1', 'fes_q9_2', 'height', 'weight', 'BMI', 'vol', 'age', 'nihtbx_totalcomp_uncorrected', 'nihtbx_fluidcomp_uncorrected', 'nihtbx_pattern_uncorrected', 'nihtbx_picture_uncorrected', 'nihtbx_list_uncorrected', 'nihtbx_flanker_uncorrected', 'nihtbx_cardsort_uncorrected', 'nihtbx_cryst_uncorrected', 'nihtbx_reading_uncorrected', 'nihtbx_picvocab_uncorrected', 'poa_total_6month_follow_up', 'friends', 'close_friends', 'upps_negative_urgency', 'upps_lack_of_planning', 'upps_sensation_seeking', 'upps_positive_urgency', 'upps_lack_of_perseverance', 'upps_total', 'AnxDep.CBCL', 'WithDep.CBCL', 'Somatic.CBCL', 'Social.CBCL', 'Thought.CBCL', 'Attention.CBCL', 'RuleBreak.CBCL', 'Aggressive.CBCL', 'Internal.CBCL', 'External.CBCL', 'TotProb.CBCL', 'Depress.CBCL', 'AnxDisord.CBCL', 'SomaticPr.CBCL', 'ADHD.CBCL', 'Opposit.CBCL', 'Conduct.CBCL', 'Sluggish.Cognitive.Tempo..SCT..CBCL', 'Obsessive.Compulsive.Problems..OCD..CBCL', 'Stress.CBCL', 'Internal.and.External.Comobidity', 'HC_PSD', 'HC_CHM', 'Ne_EN', 'Ne_PN', 'Ab_PA', 'HC_HSA', 'HC_MIH', 'Ab', 'HC', 'Ne', 'ELS_total', 'mania_score_1_year_follow_up', 'mania_binary_1_year_follow_up', 'DIMS_baseline', 'SH_baseline', 'SWTD_baseline', 'SBD_baseline', 'DA_baseline', 'DOES_baseline', 'totalSDS_baseline', 'totalBIS', 'totalBAS', 'PPSP_frequency', 'PPSP_distress']

# %% [markdown]
# # For getting feature importance

# %%
def feature(Num_feat, clf, test_data_processed, features):
    importance =clf.feature_importances_
    #plt.plot(importance)
    #plt.show()
    labels_importance=importance.argsort()[::-1]

    importance_sort = np.sort(importance)[::-1]

    feat_name_sort=test_data_processed[features].columns[labels_importance]
    important_features = pd.DataFrame() 
    
    for i in range (Num_feat):
        feature = pd.DataFrame([[feat_name_sort[i],importance_sort[i]]], columns = ['feature name', 'ratio'])
        important_features=pd.concat([important_features,feature])

    return important_features.reset_index(drop=True)

# %% [markdown]
# # Define function for preprocessing for Cross validation

# %%
def preproecessing (train_data, test_data, NUM_FOLDS):
    test_data_processed= test_data.fillna(0).reset_index(drop=True)
    train_data_processed = train_data.fillna(0).reset_index(drop=True)
    
    # 추가? 값 변경?
    test_data_processed["kfold"] = -1
    train_data_processed["kfold"] = -1

    # frac: 전체 row 중 몇 %를 반환할 지 결정 -> frac=1을 설정해서 모든 데이터를 반환
    # random_state: 추후 이것과 동일한 샘플링을 재현하기 위함
    # sample: 데이터에서 임의의 샘플 선정 -> frac=1이면 전체 data의 순서만 임의로 바뀜
    train_data_processed = train_data_processed.sample(frac=1,random_state=2020).reset_index(drop=True)

    kf = KFold(n_splits=NUM_FOLDS)
    # enumerate: 각 split된 data set 순서대로 index를 함께 반환
    for fold, (trn_, val_) in enumerate(kf.split(X=train_data_processed, y=train_data_processed)):
        # 이 부분 loc에 val_이 어떻게 들어갈 수 있는지 train_data_processed 구조 살펴보기
        train_data_processed.loc[val_, 'kfold'] = fold
    
    print("done preprocessing")
    return train_data_processed, test_data_processed

# %% [markdown]
# # Finding best parameters

# %%
# Augmented
import torch
import itertools
from sklearn.metrics import confusion_matrix
from pytorch_tabnet.tab_model import TabNetClassifier
from sklearn.metrics import roc_auc_score, accuracy_score
from tqdm.notebook import tqdm


def find_bestpar(fold, train_data_processed, test_data_processed, features):
    
    """test data 생성"""
    X_test = test_data_processed[features].values
    Y_test = test_data_processed[target].values
    
    # Store maximum auc
    max_auc= 0
    # Store maximum hypterparameter set
    max_hy = []
    
    # define hyperparameter space : learning rate, 
    n_ = [4,8,16]                              # 
    lr_ = [2e-2, 1e-2, 5e-3, 2e-3, 1e-3, 1e-4] # learning rate
    w_ = [0.01, 0.001, 0.0001]                 # weight decay
    g_ = [0.95, 0.99, 0.9]                     # scheduler params - gamma
    ss_ = [10, 20, 30]                         # scheduler params - step_size
    
    # Orginal hyperparameter space 
    """
    # define hyperparameter space (quick version)
    n_ = [4,8]
    lr_ = [2e-2,1e-2, 5e-3, 2e-3, 1e-3, 1e-4]
    w_ = [0.01, 0.001, 0.0001]
    g_ = [0.95, 0.99]
    ss_ = [10, 20]
    """
    all_ = [n_, lr_, w_, g_, ss_]
    h_space = [s for s in itertools.product(*all_)]
    
    for hy in tqdm(h_space):
        """===================Cross Validation==================="""
        
        """validation & test 결과"""
        valid_res = []
        test_auc_res = []
        test_acc_res = []

        for i in range(fold):
            #print("fold ", i)
            # 5개의 fold 사용했으므로 변수 fold 값은 차례대로 0,1,2,3,4 중 하나
            df_train = train_data_processed[train_data_processed.kfold != i]  # 5개 중 4개 train에 할당
            df_valid = train_data_processed[train_data_processed.kfold == i]  # 5개 중 1개 validation에 할당
            
            X_train = df_train[features].values
            Y_train = df_train[target].values
            
            X_valid = df_valid[features].values
            Y_valid = df_valid[target].values
            
            
            clf = TabNetClassifier(n_a = hy[0],
                                   n_d = hy[0],
                                   optimizer_params = dict(lr=hy[1], weight_decay=hy[2]),
                                   scheduler_params={"step_size":hy[4], "gamma":hy[3]},
                                   scheduler_fn=torch.optim.lr_scheduler.StepLR,
                                   verbose=0)

            clf.fit(X_train, Y_train, eval_set=[(X_train, Y_train), (X_valid, Y_valid)], 
                    eval_name=['train', 'valid'], eval_metric=['auc'],
                    max_epochs=200 , patience=20)
       
            preds_acc = clf.predict(X_test)
            preds_prob = clf.predict_proba(X_test)
            test_auc = roc_auc_score(y_score=preds_prob[:,1], y_true=Y_test)
            test_acc = accuracy_score(preds_acc, Y_test)
            
            valid_res.append(clf.best_cost)
            test_auc_res.append(test_auc)
            test_acc_res.append(test_acc)
            print('[%3d/%4d] '%(i+1, fold),'Valid score: %2f'% clf.best_cost, 'Test AUC: %.3f%%'%test_auc, 'Test ACC: %.3f%%'%test_acc)
    
        #print(valid_res)
        #print(test_auc_res)
        #print(test_acc_res)
        """valid와 test의 평균, 표준편차 출력"""
        print("=====parameter별 valid, test score=====")
        print("Validation 평균: %3f"%np.mean(valid_res), "Test AUC 평균: %3f"%np.mean(test_auc_res), "Test ACC 평균: %3f"%np.mean(test_acc_res))

        if np.mean(test_auc_res)>max_auc:
            print("Find new maximum AUC!!")
            max_hy = hy
            max_auc = np.mean(test_auc_res)
    
    return max_hy

# %% [markdown]
# # Train with best parameter

# %%
def bestpar_tuning(fold, train_data_processed, test_data_processed, max_hy, features):
 
    hy = max_hy
    print("Max hy:" ,hy)
    
    """validation & test 결과"""
    valid_res = []
    test_auc_res = []
    test_ac_resc = []
    
    for i in range(fold):
            # 5개의 fold 사용했으므로 변수 fold 값은 차례대로 0,1,2,3,4 중 하나
            df_train = train_data_processed[train_data_processed.kfold != i]  # 5개 중 4개 train에 할당
            df_valid = train_data_processed[train_data_processed.kfold == i]  # 5개 중 1개 validation에 할당
            
            X_train = df_train[features].values
            Y_train = df_train[target].values
            
            X_valid = df_valid[features].values
            Y_valid = df_valid[target].values
            
            
            clf = TabNetClassifier(n_a = hy[0],
                                   n_d = hy[0],
                                   optimizer_params = dict(lr=hy[1], weight_decay=hy[2]),
                                   scheduler_params={"step_size":hy[4], "gamma":hy[3]},
                                   scheduler_fn=torch.optim.lr_scheduler.StepLR,
                                   verbose=0)

            clf.fit(X_train, Y_train, eval_set=[(X_train, Y_train), (X_valid, Y_valid)], 
                        eval_name=['train', 'valid'], eval_metric=['auc'],
                        max_epochs=200 , patience=20)

            preds_acc = clf.predict(X_test)
            preds_prob = clf.predict_proba(X_test)
            test_auc = roc_auc_score(y_score=preds_prob[:,1], y_true=Y_test)
            test_acc = accuracy_score(preds_acc, Y_test)

            TN, FP, FN, TP = confusion_matrix(y_true=Y_test, y_pred = clf.predict(X_test)).ravel()
            sensitivity =TP/(TP+FN)
            specificity =TN/(TN+FP)
            PPV = TP/(TP+FP)
            NPV = TN/(TN+FN)
            Accuracy = TP+FP/(TN+ FP+ FN + TP)
            
            valid_res.append(clf.best_cost)
            test_auc_res.append(test_auc)
            test_acc_res.append(test_acc)
            print('[%3d/%4d] '%(i+1, fold),'Valid score: %2f'% clf.best_cost, 'Test AUC: %.3f%%'%test_auc, 'Test ACC: %.3f%%'%test_acc)

    """valid와 test의 평균, 표준편차 출력"""
    print("Validation 평균: %3f"%np.mean(valid_res), "Test AUC 평균: "%np.mean(test_auc_res), "Test ACC 평균: "%np.mean(test_acc_res))
    
    return test_auc, clf, preds_prob, sensitivity, specificity, PPV, NPV, Accuracy

# %% [markdown]
# # Run function, Split data and and cross validation. This needs to be modified

# %%
def run(train_data_processed, test_data_processed, fold, Num_feat, features):
    
    print("-------------------------------Training Begining-------------------------------")
    n_ = [4,8,16]
    lr_ = [2e-2, 1e-2, 5e-3, 2e-3, 1e-3, 1e-4]
    w_ = [0.01, 0.001, 0.0001]
    g_ = [0.95, 0.99, 0.9]
    ss_ = [10, 20, 30]
    all_ = [n_, lr_, w_, g_, ss_]
    h_space = [s for s in itertools.product(*all_)]
    
    # Start training
    max_hy = find_bestpar(fold, train_data_processed, test_data_processed, features)
    
    # if you want to just test the code, you should use this
    # max_hy = h_space[0]
    print("Found maximum hyperparmeter, now work with that")
    
    print("-------------------------------Testing Begining-------------------------------")
    test_auc, clf, preds_prob, sensitivity, specificity, PPV, NPV, Accuracy = bestpar_tuning(fold, train_data_processed, test_data_processed, max_hy, features)
    
    #print("-------------------------------Important Feature-------------------------------")
    import_feat=feature(Num_feat, clf, test_data_processed, features)
    preds_val_prob = clf.predict_proba(X_valid)

    return test_auc, Y_test, X_test, clf, preds_prob, import_feat, Y_valid, preds_val_prob

# %% [markdown]
# # Final training function

# %%
def hyperparametertuning_CV (train_data, test_data, target, unused_feat, Num_FOLDS, Num_feat):
    CV_auc_all = []
    import_feat_every = pd.DataFrame()
    
    # Data processing
    train_data_processed, test_data_processed = preproecessing (train_data, test_data, Num_FOLDS)
    
    features_all = [col for col in train_data_processed.columns if col not in unused_feat + [target]] 
    # in rsfMRI, those are some how wrong data.
    features_mri = [col for col in mri if col not in 'rsfmri_cor_network.gordon_subcort.aseg_visitid']  
    features_pheno = [col for col in train_data_processed.columns if col not in unused_feat + [target] +mri] 
    
    print("all")
    test_auc_all, Y_test_all, X_test_all, clf_all, preds_prob_all, import_feat_all, Y_valid_all, preds_val_prob_all = run(train_data_processed,
                                                                             test_data_processed,
                                                                             5, 
                                                                             Num_feat, 
                                                                             features_all)

    print("mri")
    test_auc_mri, Y_test_mri, X_test_mri, clf_mri, preds_prob_mri, import_feat_mri, Y_valid_mri, preds_val_prob_mri = run(train_data_processed, 
                                                                            test_data_processed,
                                                                            5,
                                                                            Num_feat,
                                                                            features_mri)  

    # rsfmri 이전 column에서 abcd 사이트, 타겟 제외
    print("pyschosocial")
    test_auc_pheno, Y_test_pheno, X_test_pheno, clf_pheno, preds_prob_pheno, import_feat_pheno, Y_valid_pheno, preds_val_prob_pheno = run(train_data_processed, 
                                                                                    test_data_processed, 
                                                                                    5,
                                                                                    Num_feat, 
                                                                                    features_pheno)
    
    return X_test_all, clf_all, X_test_pheno, clf_pheno, X_test_mri, clf_mri, test_auc_all, test_auc_pheno, test_auc_mri, import_feat_all, import_feat_pheno, import_feat_mri, Y_test_all , preds_prob_all, Y_test_pheno , preds_prob_pheno, Y_test_mri , preds_prob_mri, Y_valid_all, preds_val_prob_all, Y_valid_pheno, preds_val_prob_pheno, Y_valid_mri, preds_val_prob_mri

# %% [markdown]
# # Main code

# %%
X_test_all, clf_all, X_test_pheno, clf_pheno, X_test_mri, clf_mri, test_auc_all, test_auc_pheno, test_auc_mri, import_feat_all, import_feat_pheno, import_feat_mri, Y_test_all , preds_prob_all, Y_test_pheno , preds_prob_pheno, Y_test_mri, preds_prob_mri, Y_valid_all, preds_val_prob_all, Y_valid_pheno, preds_val_prob_pheno, Y_valid_mri, preds_val_prob_mri = hyperparametertuning_CV (train_data, test_data, target, unused_feat, Num_FOLDS, Num_feat)
# Out:
# done preprocessing
# all
# -------------------------------Training Begining-------------------------------
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=486.0), HTML(value='')))
# Device used : cuda
#
# Early stopping occured at epoch 50 with best_epoch = 30 and best_valid_auc = 0.79436
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.794362 Test AUC: 0.709% Test ACC: 0.504%
# Device used : cuda
#
# Early stopping occured at epoch 45 with best_epoch = 25 and best_valid_auc = 0.77693
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.776934 Test AUC: 0.703% Test ACC: 0.504%
# Device used : cuda
#
# Early stopping occured at epoch 75 with best_epoch = 55 and best_valid_auc = 0.79064
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.790637 Test AUC: 0.675% Test ACC: 0.512%
# Device used : cuda
#
# Early stopping occured at epoch 43 with best_epoch = 23 and best_valid_auc = 0.79636
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.796363 Test AUC: 0.714% Test ACC: 0.504%
# Device used : cuda
#
# Early stopping occured at epoch 59 with best_epoch = 39 and best_valid_auc = 0.76445
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.764447 Test AUC: 0.695% Test ACC: 0.504%
# =====parameter별 valid, test score=====
# Validation 평균: 0.784549 Test AUC 평균: 0.699009 Test ACC 평균: 0.505753
# Find new maximum AUC!!
# Device used : cuda
#
# Early stopping occured at epoch 70 with best_epoch = 50 and best_valid_auc = 0.78389
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.783886 Test AUC: 0.710% Test ACC: 0.521%
# Device used : cuda
#
# Early stopping occured at epoch 44 with best_epoch = 24 and best_valid_auc = 0.77225
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.772249 Test AUC: 0.690% Test ACC: 0.504%
# Device used : cuda
#
# Early stopping occured at epoch 49 with best_epoch = 29 and best_valid_auc = 0.78725
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.787245 Test AUC: 0.705% Test ACC: 0.504%
# Device used : cuda
#
# Early stopping occured at epoch 69 with best_epoch = 49 and best_valid_auc = 0.81144
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.811436 Test AUC: 0.688% Test ACC: 0.504%
# Device used : cuda
#
# Early stopping occured at epoch 63 with best_epoch = 43 and best_valid_auc = 0.77515
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.775150 Test AUC: 0.688% Test ACC: 0.504%
# =====parameter별 valid, test score=====
# Validation 평균: 0.785993 Test AUC 평균: 0.696247 Test ACC 평균: 0.507397
# Device used : cuda
#
# Early stopping occured at epoch 68 with best_epoch = 48 and best_valid_auc = 0.79438
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.794375 Test AUC: 0.689% Test ACC: 0.504%
# Device used : cuda
#
# Early stopping occured at epoch 64 with best_epoch = 44 and best_valid_auc = 0.7734
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.773403 Test AUC: 0.698% Test ACC: 0.507%
# Device used : cuda
#
# Early stopping occured at epoch 57 with best_epoch = 37 and best_valid_auc = 0.8009
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.800897 Test AUC: 0.701% Test ACC: 0.523%
# Device used : cuda
#
# Early stopping occured at epoch 64 with best_epoch = 44 and best_valid_auc = 0.8032
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.803205 Test AUC: 0.714% Test ACC: 0.504%
# Device used : cuda
#
# Early stopping occured at epoch 57 with best_epoch = 37 and best_valid_auc = 0.77114
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.771142 Test AUC: 0.702% Test ACC: 0.504%
# =====parameter별 valid, test score=====
# Validation 평균: 0.788604 Test AUC 평균: 0.700643 Test ACC 평균: 0.508493
# Find new maximum AUC!!
# Device used : cuda
#
# Early stopping occured at epoch 72 with best_epoch = 52 and best_valid_auc = 0.79834
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.798344 Test AUC: 0.700% Test ACC: 0.504%
# Device used : cuda
#
# Early stopping occured at epoch 44 with best_epoch = 24 and best_valid_auc = 0.7801
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.780099 Test AUC: 0.713% Test ACC: 0.504%
# Device used : cuda
#
# Early stopping occured at epoch 77 with best_epoch = 57 and best_valid_auc = 0.79835
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.798353 Test AUC: 0.691% Test ACC: 0.515%
# Device used : cuda
#
# Early stopping occured at epoch 59 with best_epoch = 39 and best_valid_auc = 0.8093
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.809297 Test AUC: 0.700% Test ACC: 0.504%
# Device used : cuda
#
# Early stopping occured at epoch 60 with best_epoch = 40 and best_valid_auc = 0.76745
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.767448 Test AUC: 0.697% Test ACC: 0.504%
# =====parameter별 valid, test score=====
# Validation 평균: 0.790708 Test AUC 평균: 0.700054 Test ACC 평균: 0.506301
# Device used : cuda
#
# Early stopping occured at epoch 63 with best_epoch = 43 and best_valid_auc = 0.79483
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.794828 Test AUC: 0.716% Test ACC: 0.504%
# Device used : cuda
#
# Early stopping occured at epoch 87 with best_epoch = 67 and best_valid_auc = 0.77703
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.777029 Test AUC: 0.694% Test ACC: 0.507%
# Device used : cuda
#
# Early stopping occured at epoch 46 with best_epoch = 26 and best_valid_auc = 0.79039
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.790392 Test AUC: 0.721% Test ACC: 0.504%
# Device used : cuda
#
# Early stopping occured at epoch 92 with best_epoch = 72 and best_valid_auc = 0.80481
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.804807 Test AUC: 0.691% Test ACC: 0.504%
# Device used : cuda
#
# Early stopping occured at epoch 73 with best_epoch = 53 and best_valid_auc = 0.77392
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.773922 Test AUC: 0.714% Test ACC: 0.504%
# =====parameter별 valid, test score=====
# Validation 평균: 0.788196 Test AUC 평균: 0.707038 Test ACC 평균: 0.504658
# Find new maximum AUC!!
# Device used : cuda
#
# Early stopping occured at epoch 116 with best_epoch = 96 and best_valid_auc = 0.80824
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.808241 Test AUC: 0.702% Test ACC: 0.504%
# Device used : cuda
#
# Early stopping occured at epoch 50 with best_epoch = 30 and best_valid_auc = 0.77366
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.773661 Test AUC: 0.717% Test ACC: 0.504%
# Device used : cuda
#
# Early stopping occured at epoch 54 with best_epoch = 34 and best_valid_auc = 0.79055
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.790551 Test AUC: 0.705% Test ACC: 0.521%
# Device used : cuda
#
# Early stopping occured at epoch 72 with best_epoch = 52 and best_valid_auc = 0.80638
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.806383 Test AUC: 0.701% Test ACC: 0.504%
# Device used : cuda
#
# Early stopping occured at epoch 48 with best_epoch = 28 and best_valid_auc = 0.77056
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.770559 Test AUC: 0.697% Test ACC: 0.504%
# =====parameter별 valid, test score=====
# Validation 평균: 0.789879 Test AUC 평균: 0.704252 Test ACC 평균: 0.507397
# Device used : cuda
#
# Early stopping occured at epoch 62 with best_epoch = 42 and best_valid_auc = 0.78912
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.789124 Test AUC: 0.692% Test ACC: 0.521%
# Device used : cuda
#
# Early stopping occured at epoch 55 with best_epoch = 35 and best_valid_auc = 0.78369
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.783691 Test AUC: 0.715% Test ACC: 0.504%
# Device used : cuda
#
# Early stopping occured at epoch 53 with best_epoch = 33 and best_valid_auc = 0.78961
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.789610 Test AUC: 0.710% Test ACC: 0.504%
# Device used : cuda
#
# Early stopping occured at epoch 63 with best_epoch = 43 and best_valid_auc = 0.81233
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.812334 Test AUC: 0.703% Test ACC: 0.515%
# Device used : cuda
#
# Early stopping occured at epoch 54 with best_epoch = 34 and best_valid_auc = 0.76617
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.766175 Test AUC: 0.696% Test ACC: 0.504%
# =====parameter별 valid, test score=====
# Validation 평균: 0.788187 Test AUC 평균: 0.703117 Test ACC 평균: 0.509589
# Device used : cuda
#
# Early stopping occured at epoch 54 with best_epoch = 34 and best_valid_auc = 0.79348
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.793476 Test AUC: 0.716% Test ACC: 0.504%
# Device used : cuda
#
# Early stopping occured at epoch 44 with best_epoch = 24 and best_valid_auc = 0.77026
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.770259 Test AUC: 0.690% Test ACC: 0.504%
# Device used : cuda
#
# Early stopping occured at epoch 50 with best_epoch = 30 and best_valid_auc = 0.79343
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.793432 Test AUC: 0.716% Test ACC: 0.504%
# Device used : cuda
#
# Early stopping occured at epoch 62 with best_epoch = 42 and best_valid_auc = 0.80661
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.806609 Test AUC: 0.694% Test ACC: 0.507%
# Device used : cuda
#
# Early stopping occured at epoch 62 with best_epoch = 42 and best_valid_auc = 0.76942
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.769423 Test AUC: 0.710% Test ACC: 0.504%
# =====parameter별 valid, test score=====
# Validation 평균: 0.786640 Test AUC 평균: 0.705273 Test ACC 평균: 0.504658
# Device used : cuda
#
# Early stopping occured at epoch 64 with best_epoch = 44 and best_valid_auc = 0.79988
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.799876 Test AUC: 0.711% Test ACC: 0.504%
# Device used : cuda
#
# Early stopping occured at epoch 65 with best_epoch = 45 and best_valid_auc = 0.7758
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.775804 Test AUC: 0.717% Test ACC: 0.504%
# Device used : cuda
#
# Early stopping occured at epoch 56 with best_epoch = 36 and best_valid_auc = 0.80155
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.801553 Test AUC: 0.701% Test ACC: 0.507%
# Device used : cuda
#
# Early stopping occured at epoch 77 with best_epoch = 57 and best_valid_auc = 0.80064
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.800640 Test AUC: 0.696% Test ACC: 0.504%
# Device used : cuda
#
# Early stopping occured at epoch 83 with best_epoch = 63 and best_valid_auc = 0.78061
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.780613 Test AUC: 0.691% Test ACC: 0.518%
# =====parameter별 valid, test score=====
# Validation 평균: 0.791697 Test AUC 평균: 0.703345 Test ACC 평균: 0.507397
# Device used : cuda
#
# Early stopping occured at epoch 58 with best_epoch = 38 and best_valid_auc = 0.76796
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.767962 Test AUC: 0.695% Test ACC: 0.510%
# Device used : cuda
#
# Early stopping occured at epoch 75 with best_epoch = 55 and best_valid_auc = 0.74448
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.744483 Test AUC: 0.671% Test ACC: 0.512%
# Device used : cuda
#
# Early stopping occured at epoch 74 with best_epoch = 54 and best_valid_auc = 0.7864
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.786404 Test AUC: 0.680% Test ACC: 0.504%
# Device used : cuda
#
# Early stopping occured at epoch 97 with best_epoch = 77 and best_valid_auc = 0.78661
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.786607 Test AUC: 0.669% Test ACC: 0.504%
# Device used : cuda
#
# Early stopping occured at epoch 51 with best_epoch = 31 and best_valid_auc = 0.75698
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.756977 Test AUC: 0.698% Test ACC: 0.504%
# =====parameter별 valid, test score=====
# Validation 평균: 0.768486 Test AUC 평균: 0.682555 Test ACC 평균: 0.506849
# Device used : cuda
#
# Early stopping occured at epoch 50 with best_epoch = 30 and best_valid_auc = 0.77241
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.772411 Test AUC: 0.711% Test ACC: 0.521%
# Device used : cuda
#
# Early stopping occured at epoch 84 with best_epoch = 64 and best_valid_auc = 0.75042
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.750418 Test AUC: 0.690% Test ACC: 0.523%
# Device used : cuda
#
# Early stopping occured at epoch 69 with best_epoch = 49 and best_valid_auc = 0.79731
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.797307 Test AUC: 0.667% Test ACC: 0.512%
# Device used : cuda
#
# Early stopping occured at epoch 60 with best_epoch = 40 and best_valid_auc = 0.77832
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.778318 Test AUC: 0.697% Test ACC: 0.504%
# Device used : cuda
#
# Early stopping occured at epoch 60 with best_epoch = 40 and best_valid_auc = 0.76453
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.764530 Test AUC: 0.698% Test ACC: 0.504%
# =====parameter별 valid, test score=====
# Validation 평균: 0.772597 Test AUC 평균: 0.692620 Test ACC 평균: 0.512877
# Device used : cuda
#
# Early stopping occured at epoch 62 with best_epoch = 42 and best_valid_auc = 0.77218
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.772178 Test AUC: 0.685% Test ACC: 0.523%
# Device used : cuda
#
# Early stopping occured at epoch 59 with best_epoch = 39 and best_valid_auc = 0.75561
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.755612 Test AUC: 0.675% Test ACC: 0.512%
# Device used : cuda
#
# Early stopping occured at epoch 93 with best_epoch = 73 and best_valid_auc = 0.78359
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.783589 Test AUC: 0.605% Test ACC: 0.523%
# Device used : cuda
#
# Early stopping occured at epoch 86 with best_epoch = 66 and best_valid_auc = 0.78867
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.788674 Test AUC: 0.689% Test ACC: 0.515%
# Device used : cuda
#
# Early stopping occured at epoch 73 with best_epoch = 53 and best_valid_auc = 0.76213
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.762129 Test AUC: 0.692% Test ACC: 0.504%
# =====parameter별 valid, test score=====
# Validation 평균: 0.772437 Test AUC 평균: 0.669379 Test ACC 평균: 0.515616
# Device used : cuda
#
# Early stopping occured at epoch 38 with best_epoch = 18 and best_valid_auc = 0.77631
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.776313 Test AUC: 0.669% Test ACC: 0.512%
# Device used : cuda
#
# Early stopping occured at epoch 63 with best_epoch = 43 and best_valid_auc = 0.75319
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.753188 Test AUC: 0.676% Test ACC: 0.504%
# Device used : cuda
#
# Early stopping occured at epoch 76 with best_epoch = 56 and best_valid_auc = 0.77585
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.775846 Test AUC: 0.664% Test ACC: 0.510%
# Device used : cuda
#
# Early stopping occured at epoch 92 with best_epoch = 72 and best_valid_auc = 0.79209
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.792086 Test AUC: 0.669% Test ACC: 0.515%
# Device used : cuda
#
# Early stopping occured at epoch 63 with best_epoch = 43 and best_valid_auc = 0.7659
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.765900 Test AUC: 0.696% Test ACC: 0.523%
# =====parameter별 valid, test score=====
# Validation 평균: 0.772667 Test AUC 평균: 0.674724 Test ACC 평균: 0.512877
# Device used : cuda
#
# Early stopping occured at epoch 67 with best_epoch = 47 and best_valid_auc = 0.77904
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.779037 Test AUC: 0.688% Test ACC: 0.515%
# Device used : cuda
#
# Early stopping occured at epoch 88 with best_epoch = 68 and best_valid_auc = 0.76001
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.760006 Test AUC: 0.657% Test ACC: 0.518%
# Device used : cuda
#
# Early stopping occured at epoch 64 with best_epoch = 44 and best_valid_auc = 0.78241
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.782410 Test AUC: 0.708% Test ACC: 0.512%
# Device used : cuda
#
# Early stopping occured at epoch 50 with best_epoch = 30 and best_valid_auc = 0.77324
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.773239 Test AUC: 0.691% Test ACC: 0.504%
# Device used : cuda
#
# Early stopping occured at epoch 69 with best_epoch = 49 and best_valid_auc = 0.75401
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.754014 Test AUC: 0.659% Test ACC: 0.504%
# =====parameter별 valid, test score=====
# Validation 평균: 0.769741 Test AUC 평균: 0.680549 Test ACC 평균: 0.510685
# Device used : cuda
#
# Early stopping occured at epoch 67 with best_epoch = 47 and best_valid_auc = 0.78894
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.788941 Test AUC: 0.695% Test ACC: 0.523%
# Device used : cuda
#
# Early stopping occured at epoch 64 with best_epoch = 44 and best_valid_auc = 0.7586
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.758600 Test AUC: 0.701% Test ACC: 0.526%
# Device used : cuda
#
# Early stopping occured at epoch 72 with best_epoch = 52 and best_valid_auc = 0.7904
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.790405 Test AUC: 0.638% Test ACC: 0.504%
# Device used : cuda
#
# Early stopping occured at epoch 67 with best_epoch = 47 and best_valid_auc = 0.78144
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.781438 Test AUC: 0.676% Test ACC: 0.512%
# Device used : cuda
#
# Early stopping occured at epoch 77 with best_epoch = 57 and best_valid_auc = 0.7622
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.762201 Test AUC: 0.695% Test ACC: 0.504%
# =====parameter별 valid, test score=====
# Validation 평균: 0.776317 Test AUC 평균: 0.680891 Test ACC 평균: 0.513973
# Device used : cuda
#
# Early stopping occured at epoch 64 with best_epoch = 44 and best_valid_auc = 0.78958
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.789580 Test AUC: 0.694% Test ACC: 0.518%
# Device used : cuda
#
# Early stopping occured at epoch 72 with best_epoch = 52 and best_valid_auc = 0.74736
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.747355 Test AUC: 0.666% Test ACC: 0.518%
# Device used : cuda
#
# Early stopping occured at epoch 83 with best_epoch = 63 and best_valid_auc = 0.772
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.771997 Test AUC: 0.679% Test ACC: 0.521%
# Device used : cuda
#
# Early stopping occured at epoch 73 with best_epoch = 53 and best_valid_auc = 0.79527
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.795271 Test AUC: 0.673% Test ACC: 0.504%
# Device used : cuda
#
# Early stopping occured at epoch 75 with best_epoch = 55 and best_valid_auc = 0.76297
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.762966 Test AUC: 0.710% Test ACC: 0.507%
# =====parameter별 valid, test score=====
# Validation 평균: 0.773434 Test AUC 평균: 0.684344 Test ACC 평균: 0.513425
# Device used : cuda
#
# Early stopping occured at epoch 56 with best_epoch = 36 and best_valid_auc = 0.7686
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.768601 Test AUC: 0.662% Test ACC: 0.518%
# Device used : cuda
#
# Early stopping occured at epoch 78 with best_epoch = 58 and best_valid_auc = 0.75514
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.755144 Test AUC: 0.645% Test ACC: 0.523%
# Device used : cuda
#
# Early stopping occured at epoch 56 with best_epoch = 36 and best_valid_auc = 0.76077
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.760770 Test AUC: 0.675% Test ACC: 0.507%
# Device used : cuda
#
# Early stopping occured at epoch 56 with best_epoch = 36 and best_valid_auc = 0.7764
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.776399 Test AUC: 0.691% Test ACC: 0.504%
# Device used : cuda
#
# Early stopping occured at epoch 58 with best_epoch = 38 and best_valid_auc = 0.75387
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.753865 Test AUC: 0.705% Test ACC: 0.504%
# =====parameter별 valid, test score=====
# Validation 평균: 0.762956 Test AUC 평균: 0.675661 Test ACC 평균: 0.511233
# Device used : cuda
#
# Early stopping occured at epoch 79 with best_epoch = 59 and best_valid_auc = 0.78137
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.781375 Test AUC: 0.687% Test ACC: 0.523%
# Device used : cuda
#
# Early stopping occured at epoch 78 with best_epoch = 58 and best_valid_auc = 0.75876
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.758756 Test AUC: 0.671% Test ACC: 0.532%
# Device used : cuda
#
# Early stopping occured at epoch 63 with best_epoch = 43 and best_valid_auc = 0.78794
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.787941 Test AUC: 0.689% Test ACC: 0.504%
# Device used : cuda
#
# Early stopping occured at epoch 73 with best_epoch = 53 and best_valid_auc = 0.7851
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.785101 Test AUC: 0.654% Test ACC: 0.512%
# Device used : cuda
#
# Early stopping occured at epoch 68 with best_epoch = 48 and best_valid_auc = 0.75921
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.759215 Test AUC: 0.680% Test ACC: 0.504%
# =====parameter별 valid, test score=====
# Validation 평균: 0.774478 Test AUC 평균: 0.676423 Test ACC 평균: 0.515068
# Device used : cuda
#
# Early stopping occured at epoch 78 with best_epoch = 58 and best_valid_auc = 0.7645
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.764499 Test AUC: 0.716% Test ACC: 0.504%
# Device used : cuda
#
# Early stopping occured at epoch 58 with best_epoch = 38 and best_valid_auc = 0.75379
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.753786 Test AUC: 0.687% Test ACC: 0.507%
# Device used : cuda
#
# Early stopping occured at epoch 107 with best_epoch = 87 and best_valid_auc = 0.79598
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.795975 Test AUC: 0.677% Test ACC: 0.507%
# Device used : cuda
#
# Early stopping occured at epoch 32 with best_epoch = 12 and best_valid_auc = 0.75717
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.757165 Test AUC: 0.663% Test ACC: 0.504%
# Device used : cuda
#
# Early stopping occured at epoch 57 with best_epoch = 37 and best_valid_auc = 0.75387
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.753871 Test AUC: 0.695% Test ACC: 0.512%
# =====parameter별 valid, test score=====
# Validation 평균: 0.765059 Test AUC 평균: 0.687644 Test ACC 평균: 0.506849
# Device used : cuda
#
# Early stopping occured at epoch 70 with best_epoch = 50 and best_valid_auc = 0.75868
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.758678 Test AUC: 0.684% Test ACC: 0.507%
# Device used : cuda
#
# Early stopping occured at epoch 42 with best_epoch = 22 and best_valid_auc = 0.76672
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.766721 Test AUC: 0.688% Test ACC: 0.499%
# Device used : cuda
#
# Early stopping occured at epoch 50 with best_epoch = 30 and best_valid_auc = 0.7754
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.775402 Test AUC: 0.698% Test ACC: 0.499%
# Device used : cuda
#
# Early stopping occured at epoch 48 with best_epoch = 28 and best_valid_auc = 0.76841
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.768407 Test AUC: 0.671% Test ACC: 0.510%
# Device used : cuda
#
# Early stopping occured at epoch 59 with best_epoch = 39 and best_valid_auc = 0.75283
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.752832 Test AUC: 0.684% Test ACC: 0.504%
# =====parameter별 valid, test score=====
# Validation 평균: 0.764408 Test AUC 평균: 0.685053 Test ACC 평균: 0.503562
# Device used : cuda
#
# Early stopping occured at epoch 73 with best_epoch = 53 and best_valid_auc = 0.76784
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.767835 Test AUC: 0.724% Test ACC: 0.504%
# Device used : cuda
#
# Early stopping occured at epoch 42 with best_epoch = 22 and best_valid_auc = 0.76843
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.768426 Test AUC: 0.684% Test ACC: 0.501%
# Device used : cuda
#
# Early stopping occured at epoch 83 with best_epoch = 63 and best_valid_auc = 0.78732
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.787318 Test AUC: 0.669% Test ACC: 0.499%
# Device used : cuda
#
# Early stopping occured at epoch 64 with best_epoch = 44 and best_valid_auc = 0.76557
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.765570 Test AUC: 0.704% Test ACC: 0.510%
# Device used : cuda
#
# Early stopping occured at epoch 53 with best_epoch = 33 and best_valid_auc = 0.75107
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.751073 Test AUC: 0.713% Test ACC: 0.512%
# =====parameter별 valid, test score=====
# Validation 평균: 0.768045 Test AUC 평균: 0.699009 Test ACC 평균: 0.505205
# Device used : cuda
#
# Early stopping occured at epoch 63 with best_epoch = 43 and best_valid_auc = 0.76917
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.769174 Test AUC: 0.697% Test ACC: 0.507%
# Device used : cuda
#
# Early stopping occured at epoch 46 with best_epoch = 26 and best_valid_auc = 0.75059
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.750591 Test AUC: 0.670% Test ACC: 0.501%
# Device used : cuda
#
# Early stopping occured at epoch 67 with best_epoch = 47 and best_valid_auc = 0.78548
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.785483 Test AUC: 0.696% Test ACC: 0.501%
# Device used : cuda
#
# Early stopping occured at epoch 40 with best_epoch = 20 and best_valid_auc = 0.76066
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.760660 Test AUC: 0.675% Test ACC: 0.504%
# Device used : cuda
#
# Early stopping occured at epoch 87 with best_epoch = 67 and best_valid_auc = 0.76238
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.762384 Test AUC: 0.699% Test ACC: 0.512%
# =====parameter별 valid, test score=====
# Validation 평균: 0.765658 Test AUC 평균: 0.687338 Test ACC 평균: 0.505205
# Device used : cuda
#
# Early stopping occured at epoch 53 with best_epoch = 33 and best_valid_auc = 0.75809
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.758092 Test AUC: 0.706% Test ACC: 0.501%
# Device used : cuda
#
# Early stopping occured at epoch 42 with best_epoch = 22 and best_valid_auc = 0.76936
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.769363 Test AUC: 0.685% Test ACC: 0.504%
# Device used : cuda
#
# Early stopping occured at epoch 106 with best_epoch = 86 and best_valid_auc = 0.78648
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.786484 Test AUC: 0.658% Test ACC: 0.523%
# Device used : cuda
#
# Early stopping occured at epoch 47 with best_epoch = 27 and best_valid_auc = 0.76577
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.765771 Test AUC: 0.667% Test ACC: 0.504%
# Device used : cuda
#
# Early stopping occured at epoch 69 with best_epoch = 49 and best_valid_auc = 0.76738
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.767379 Test AUC: 0.709% Test ACC: 0.515%
# =====parameter별 valid, test score=====
# Validation 평균: 0.769418 Test AUC 평균: 0.685023 Test ACC 평균: 0.509589
# Device used : cuda
#
# Early stopping occured at epoch 35 with best_epoch = 15 and best_valid_auc = 0.75322
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.753223 Test AUC: 0.698% Test ACC: 0.504%
# Device used : cuda
#
# Early stopping occured at epoch 42 with best_epoch = 22 and best_valid_auc = 0.76843
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.768426 Test AUC: 0.684% Test ACC: 0.501%
# Device used : cuda
#
# Early stopping occured at epoch 89 with best_epoch = 69 and best_valid_auc = 0.79364
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.793644 Test AUC: 0.673% Test ACC: 0.507%
# Device used : cuda
#
# Early stopping occured at epoch 84 with best_epoch = 64 and best_valid_auc = 0.77292
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.772916 Test AUC: 0.705% Test ACC: 0.512%
# Device used : cuda
#
# Early stopping occured at epoch 66 with best_epoch = 46 and best_valid_auc = 0.75868
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.758678 Test AUC: 0.719% Test ACC: 0.515%
# =====parameter별 valid, test score=====
# Validation 평균: 0.769378 Test AUC 평균: 0.695916 Test ACC 평균: 0.507945
# Device used : cuda
#
# Early stopping occured at epoch 77 with best_epoch = 57 and best_valid_auc = 0.78181
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.781814 Test AUC: 0.720% Test ACC: 0.518%
# Device used : cuda
#
# Early stopping occured at epoch 57 with best_epoch = 37 and best_valid_auc = 0.75554
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.755538 Test AUC: 0.670% Test ACC: 0.504%
# Device used : cuda
#
# Early stopping occured at epoch 100 with best_epoch = 80 and best_valid_auc = 0.80175
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.801751 Test AUC: 0.677% Test ACC: 0.507%
# Device used : cuda
#
# Early stopping occured at epoch 56 with best_epoch = 36 and best_valid_auc = 0.76956
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.769563 Test AUC: 0.710% Test ACC: 0.515%
# Device used : cuda
#
# Early stopping occured at epoch 53 with best_epoch = 33 and best_valid_auc = 0.73505
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.735053 Test AUC: 0.691% Test ACC: 0.510%
# =====parameter별 valid, test score=====
# Validation 평균: 0.768744 Test AUC 평균: 0.693604 Test ACC 평균: 0.510685
# Device used : cuda
#
# Early stopping occured at epoch 35 with best_epoch = 15 and best_valid_auc = 0.75322
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.753223 Test AUC: 0.698% Test ACC: 0.504%
# Device used : cuda
#
# Early stopping occured at epoch 41 with best_epoch = 21 and best_valid_auc = 0.76844
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.768439 Test AUC: 0.686% Test ACC: 0.507%
# Device used : cuda
#
# Early stopping occured at epoch 78 with best_epoch = 58 and best_valid_auc = 0.78838
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.788385 Test AUC: 0.685% Test ACC: 0.510%
# Device used : cuda
#
# Early stopping occured at epoch 63 with best_epoch = 43 and best_valid_auc = 0.76839
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.768387 Test AUC: 0.715% Test ACC: 0.507%
# Device used : cuda
#
# Early stopping occured at epoch 75 with best_epoch = 55 and best_valid_auc = 0.76059
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.760591 Test AUC: 0.701% Test ACC: 0.507%
# =====parameter별 valid, test score=====
# Validation 평균: 0.767805 Test AUC 평균: 0.696967 Test ACC 평균: 0.506849
# Device used : cuda
#
# Early stopping occured at epoch 96 with best_epoch = 76 and best_valid_auc = 0.76903
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.769027 Test AUC: 0.697% Test ACC: 0.510%
# Device used : cuda
#
# Early stopping occured at epoch 42 with best_epoch = 22 and best_valid_auc = 0.76843
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.768426 Test AUC: 0.684% Test ACC: 0.501%
# Device used : cuda
#
# Early stopping occured at epoch 66 with best_epoch = 46 and best_valid_auc = 0.77502
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.775021 Test AUC: 0.677% Test ACC: 0.504%
# Device used : cuda
#
# Early stopping occured at epoch 65 with best_epoch = 45 and best_valid_auc = 0.76755
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.767554 Test AUC: 0.696% Test ACC: 0.510%
# Device used : cuda
#
# Early stopping occured at epoch 65 with best_epoch = 45 and best_valid_auc = 0.75139
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.751393 Test AUC: 0.711% Test ACC: 0.515%
# =====parameter별 valid, test score=====
# Validation 평균: 0.766284 Test AUC 평균: 0.692938 Test ACC 평균: 0.507945
# Device used : cuda
#
# Early stopping occured at epoch 92 with best_epoch = 72 and best_valid_auc = 0.79543
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.795427 Test AUC: 0.699% Test ACC: 0.518%
# Device used : cuda
#
# Early stopping occured at epoch 36 with best_epoch = 16 and best_valid_auc = 0.76615
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.766151 Test AUC: 0.690% Test ACC: 0.504%
# Device used : cuda
#
# Early stopping occured at epoch 69 with best_epoch = 49 and best_valid_auc = 0.7891
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.789100 Test AUC: 0.708% Test ACC: 0.504%
# Device used : cuda
#
# Early stopping occured at epoch 59 with best_epoch = 39 and best_valid_auc = 0.7991
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.799095 Test AUC: 0.717% Test ACC: 0.504%
# Device used : cuda
#
# Early stopping occured at epoch 57 with best_epoch = 37 and best_valid_auc = 0.76466
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.764662 Test AUC: 0.709% Test ACC: 0.504%
# =====parameter별 valid, test score=====
# Validation 평균: 0.782887 Test AUC 평균: 0.704732 Test ACC 평균: 0.506849
# Device used : cuda
#
# Early stopping occured at epoch 116 with best_epoch = 96 and best_valid_auc = 0.81208
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.812084 Test AUC: 0.649% Test ACC: 0.526%
# Device used : cuda
#
# Early stopping occured at epoch 78 with best_epoch = 58 and best_valid_auc = 0.77379
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.773790 Test AUC: 0.701% Test ACC: 0.518%
# Device used : cuda
#
# Early stopping occured at epoch 62 with best_epoch = 42 and best_valid_auc = 0.77987
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.779866 Test AUC: 0.713% Test ACC: 0.504%
# Device used : cuda
#
# Early stopping occured at epoch 38 with best_epoch = 18 and best_valid_auc = 0.78528
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.785282 Test AUC: 0.699% Test ACC: 0.504%
# Device used : cuda
#
# Early stopping occured at epoch 62 with best_epoch = 42 and best_valid_auc = 0.76797
# Best weights from best epoch are automatically used!
# [  5/   5]  Valid score: 0.767973 Test AUC: 0.724% Test ACC: 0.504%
# =====parameter별 valid, test score=====
# Validation 평균: 0.783799 Test AUC 평균: 0.697238 Test ACC 평균: 0.511233
# Device used : cuda
#
# Early stopping occured at epoch 76 with best_epoch = 56 and best_valid_auc = 0.79944
# Best weights from best epoch are automatically used!
# [  1/   5]  Valid score: 0.799437 Test AUC: 0.709% Test ACC: 0.504%
# Device used : cuda
#
# Early stopping occured at epoch 78 with best_epoch = 58 and best_valid_auc = 0.77767
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.777674 Test AUC: 0.704% Test ACC: 0.512%
# Device used : cuda
#
# Early stopping occured at epoch 70 with best_epoch = 50 and best_valid_auc = 0.79123
# Best weights from best epoch are automatically used!
# [  3/   5]  Valid score: 0.791226 Test AUC: 0.692% Test ACC: 0.507%
# Device used : cuda
#
# Early stopping occured at epoch 41 with best_epoch = 21 and best_valid_auc = 0.78753
# Best weights from best epoch are automatically used!
# [  4/   5]  Valid score: 0.787531 Test AUC: 0.700% Test ACC: 0.504%
# Device used : cuda
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-14c51cada839> in <module>
# ----> 1 X_test_all, clf_all, X_test_pheno, clf_pheno, X_test_mri, clf_mri, test_auc_all, test_auc_pheno, test_auc_mri, import_feat_all, import_feat_pheno, import_feat_mri, Y_test_all , preds_prob_all, Y_test_pheno , preds_prob_pheno, Y_test_mri, preds_prob_mri, Y_valid_all, preds_val_prob_all, Y_valid_pheno, preds_val_prob_pheno, Y_valid_mri, preds_val_prob_mri = hyperparametertuning_CV (train_data, test_data, target, unused_feat, Num_FOLDS, Num_feat)
#
# <ipython-input-9-8b1f715c3956> in hyperparametertuning_CV(train_data, test_data, target, unused_feat, Num_FOLDS, Num_feat)
#      16                                                                              5,
#      17                                                                              Num_feat,
# ---> 18                                                                              features_all)
#      19
#      20     print("mri")
#
# <ipython-input-8-69f405537f14> in run(train_data_processed, test_data_processed, fold, Num_feat, features)
#      11
#      12     # Start training
# ---> 13     max_hy = find_bestpar(fold, train_data_processed, test_data_processed, features)
#      14
#      15     # if you want to just test the code, you should use this
#
# <ipython-input-6-97d1ab8e41e5> in find_bestpar(fold, train_data_processed, test_data_processed, features)
#      68             clf.fit(X_train, Y_train, eval_set=[(X_train, Y_train), (X_valid, Y_valid)],
#      69                     eval_name=['train', 'valid'], eval_metric=['auc'],
# ---> 70                     max_epochs=200 , patience=20)
#      71
#      72             preds_acc = clf.predict(X_test)
#
# ~/anaconda3/lib/python3.6/site-packages/pytorch_tabnet/abstract_model.py in fit(self, X_train, y_train, eval_set, eval_name, eval_metric, loss_fn, weights, max_epochs, patience, batch_size, virtual_batch_size, num_workers, drop_last, callbacks, pin_memory)
#     171             self._callback_container.on_epoch_begin(epoch_idx)
#     172
# --> 173             self._train_epoch(train_dataloader)
#     174
#     175             # Apply predict epoch to all eval sets
#
# ~/anaconda3/lib/python3.6/site-packages/pytorch_tabnet/abstract_model.py in _train_epoch(self, train_loader)
#     344         self.network.train()
#     345
# --> 346         for batch_idx, (X, y) in enumerate(train_loader):
#     347             self._callback_container.on_batch_begin(batch_idx)
#     348
#
# ~/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     433         if self._sampler_iter is None:
#     434             self._reset()
# --> 435         data = self._next_data()
#     436         self._num_yielded += 1
#     437         if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     473     def _next_data(self):
#     474         index = self._next_index()  # may raise StopIteration
# --> 475         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     476         if self._pin_memory:
#     477             data = _utils.pin_memory.pin_memory(data)
#
# ~/anaconda3/lib/python3.6/site-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
# ---> 47         return self.collate_fn(data)
#
# ~/anaconda3/lib/python3.6/site-packages/torch/utils/data/_utils/collate.py in default_collate(batch)
#      81             raise RuntimeError('each element in list of batch should be of equal size')
#      82         transposed = zip(*batch)
# ---> 83         return [default_collate(samples) for samples in transposed]
#      84
#      85     raise TypeError(default_collate_err_msg_format.format(elem_type))
#
# ~/anaconda3/lib/python3.6/site-packages/torch/utils/data/_utils/collate.py in <listcomp>(.0)
#      81             raise RuntimeError('each element in list of batch should be of equal size')
#      82         transposed = zip(*batch)
# ---> 83         return [default_collate(samples) for samples in transposed]
#      84
#      85     raise TypeError(default_collate_err_msg_format.format(elem_type))
#
# ~/anaconda3/lib/python3.6/site-packages/torch/utils/data/_utils/collate.py in default_collate(batch)
#      61                 raise TypeError(default_collate_err_msg_format.format(elem.dtype))
#      62
# ---> 63             return default_collate([torch.as_tensor(b) for b in batch])
#      64         elif elem.shape == ():  # scalars
#      65             return torch.as_tensor(batch)
#
# ~/anaconda3/lib/python3.6/site-packages/torch/utils/data/_utils/collate.py in default_collate(batch)
#      53             storage = elem.storage()._new_shared(numel)
#      54             out = elem.new(storage)
# ---> 55         return torch.stack(batch, 0, out=out)
#      56     elif elem_type.__module__ == 'numpy' and elem_type.__name__ != 'str_' \
#      57             and elem_type.__name__ != 'string_':
#
# KeyboardInterrupt:

# %% [markdown]
# # Getting results

# %%
valid_auc_all = roc_auc_score (Y_valid_all, preds_val_prob_all[:,1])
valid_auc_pheno = roc_auc_score (Y_valid_pheno, preds_val_prob_pheno[:,1])
valid_auc_mri = roc_auc_score (Y_valid_mri, preds_val_prob_mri[:,1])

def classify (preds_prob_all, Y_test, line):
    y_pred_all = []
    for x in preds_prob_all[:,1]:
        if x > line:
            y_pred_all.append(1)
        else:
            y_pred_all.append(0)
    y_pred_all=np.array(y_pred_all)
    test_acc = accuracy_score(y_pred_all, Y_test)
    #print(test_acc)
    return y_pred_all, test_acc

def find_best_boundary(preds_prob_all,Y_test):
    results =[]
    idx =[]
    for i in  np.arange(0.01, 0.35, 0.01):
   
        idx.append(i)
        _,test_acc =classify(preds_prob_all,Y_test, i)
        results.append(test_acc)

    results
    num_idx=results.index(max(results))
    best_idx =idx[num_idx]
    #print(f'best_classify_boundary {best_idx}')
    y_pred_all,test_acc =classify(preds_prob_all, Y_test, best_idx)
    #print(f'best ACC= {test_acc}')
    return best_idx

def confusion_stuff (Y_test, preds_prob_all):
    best_idx=find_best_boundary(preds_prob_all,Y_test)
    y_pred_all, test_acc =classify (preds_prob_all, Y_test, 0.15)
    TN, FP, FN, TP = confusion_matrix(y_true=Y_test, y_pred = y_pred_all).ravel()
    print(TN,FP)
    print(FN,TP)
    
    sensitivity =TP/(TP+FN)
    specificity =TN/(TN+FP)
    PPV = TP/(TP+FP)
    NPV = TN/(TN+FN)
    Accuracy = test_acc
    return sensitivity, specificity, PPV, NPV, Accuracy

def makeround(sensitivity_all, specificity_all, PPV_all, NPV_all, Accuracy_all):
    lists = sensitivity_all, specificity_all, PPV_all, NPV_all, Accuracy_all
    new_lists=[]
    for list in lists:
        new_list =  round(list*100,2)
        new_lists.append(new_list)
    
    return new_lists[0], new_lists[1], new_lists[2], new_lists[3], new_lists[4]
        
print("<<<<All>>>>")
sensitivity_all, specificity_all, PPV_all, NPV_all, Accuracy_all = confusion_stuff(Y_test_all, preds_prob_all)
sensitivity_all, specificity_all, PPV_all, NPV_all, Accuracy_all = makeround(sensitivity_all, specificity_all, PPV_all, NPV_all, Accuracy_all)
print(f"sensitivity {sensitivity_all}% specificity {sensitivity_all}% PPV {sensitivity_all}% NPV {NPV_all}% Accuracy {Accuracy_all}% Valid_AUC {round(valid_auc_all*100,2)}% Test_AUC {round(test_auc_all*100,2)}% " )

print("<<<<psychosocial>>>>")
sensitivity_pheno, specificity_pheno, PPV_pheno, NPV_pheno, Accuracy_pheno = confusion_stuff(Y_test_pheno, preds_prob_pheno)
sensitivity_pheno, specificity_pheno, PPV_pheno, NPV_pheno, Accuracy_pheno= makeround(sensitivity_pheno, specificity_pheno, PPV_pheno, NPV_pheno, Accuracy_pheno)
print(f"sensitivity {sensitivity_pheno}% specificity {specificity_pheno}% PPV {PPV_pheno}% NPV {NPV_pheno}% Accuracy {Accuracy_pheno}% Valid_AUC {round(valid_auc_pheno*100,2)}% Test_AUC {round(test_auc_pheno*100,2)}%")

print("<<<<MRI>>>>")
sensitivity_mri, specificity_mri, PPV_mri, NPV_mri, Accuracy_mri = confusion_stuff(Y_test_mri, preds_prob_mri)
sensitivity_mri, specificity_mri, PPV_mri, NPV_mri, Accuracy_mri = makeround(sensitivity_mri, specificity_mri, PPV_mri, NPV_mri, Accuracy_mri )
print(f"sensitivity {sensitivity_mri}% specificity {specificity_mri}% PPV {PPV_mri}% NPV {NPV_mri}% Accuracy {Accuracy_mri}% Valid_AUC {round(valid_auc_mri*100,2)}% Test_AUC {round(test_auc_mri*100,2)}%")

# %% [markdown]
# # For drawing ROC curve graph

# %%
def rocvis(true , prob , label ) :
    from sklearn.metrics import roc_curve
    if type(true[0]) == str :
        from sklearn.preprocessing import LabelEncoder
        le = LabelEncoder()
        true = le.fit_transform(true)
    else :
        pass
    fpr, tpr, thresholds = roc_curve(true, prob)
    plt.plot(fpr, tpr, marker='.', label = label  )

# %% [markdown]
# # Draw ROC curve

# %%
fig , ax = plt.subplots(figsize= (20,10))
plt.plot([0, 1], [0, 1], linestyle='--')
rocvis(Y_test_all , preds_prob_all[:,1] , f"Combined:{round(test_auc_all*100, 2)}%")
rocvis(Y_test_pheno , preds_prob_pheno[:,1] , f"psychosocial:{round(test_auc_pheno*100, 2)}%")
rocvis(Y_test_mri , preds_prob_mri[:,1] , f"MRI:{round(test_auc_mri*100, 2)}%")
    #rocvis(caty_Test , catprob[:,1] , "CatBoost")
dataset_name="enbackfMRI"

plt.legend(fontsize = 40)
plt.title(dataset_name, fontsize= 50)
plt.xlabel("FP rate", fontsize =30)
plt.ylabel("TP rate", fontsize =30)
plt.xticks(size = 30)
plt.yticks(size = 30)

plt.tight_layout()
plt.savefig(f'{dataset_name}_ROC.png')

# %% [markdown]
# # For model interpretation. with subjectkey below datas are needed
#
# name_test_all, name_train_all, name_valid_all,
# name_test_pheno, name_train_pheno, name_valid_pheno,
# name_test_mri, name_train_mri, name_valid_mri,
# Y_test_all , preds_prob_all,
# Y_test_pheno , preds_prob_pheno,
# Y_test_mri , preds_prob_mri,
# Y_valid_all, preds_val_prob_all,
# Y_valid_pheno, preds_val_prob_pheno,
# Y_valid_mri, preds_val_prob_mri

# %%
def save_prob_with_true(Y_test,preds_prob, subjectkey, testORvalid, modeltype):
    
    combined_model=pd.DataFrame({f"subjectkey_{testORvalid}_{modeltype}": subjectkey, f"Y_{testORvalid}_{modeltype}":Y_test, f"preds_prob_{testORvalid}_{modeltype}" :preds_prob[:,1]} )
    combined_model.to_csv(f"{dataset_name}_combined_forROC_{modeltype}_{testORvalid}.csv")
    return combined_model

# %%
result_test_all = save_prob_with_true(Y_test_all, preds_prob_all, name_test_all, "test", "all")
result_valid_all = save_prob_with_true(Y_valid_all, preds_val_prob_all, name_valid_all, "valid", "all")

result_test_pheno = save_prob_with_true(Y_test_pheno, preds_prob_pheno, name_test_pheno, "test", "psychosocial")
result_valid_pheno = save_prob_with_true(Y_valid_pheno, preds_val_prob_pheno, name_valid_pheno, "valid", "psychosocial")

result_test_mri = save_prob_with_true(Y_test_mri, preds_prob_mri, name_test_mri, "test", "mri")
result_valid_mri = save_prob_with_true(Y_valid_mri, preds_val_prob_mri, name_valid_mri, "valid", "mri")

# %% [markdown]
# # save feature importance

# %%
import_feat_every=pd.concat([import_feat_all,import_feat_pheno, import_feat_mri])

import_feat_every.to_csv(f"{dataset_name}_features.csv")

import_feat_every

# %% [markdown]
# # Draw AUC per epochs and loss per epochs

# %%
feature_names=["Combined", "psychosocial", "MRI"]
clfs = [clf_all, clf_pheno, clf_mri ]
simple_name = "enbackfMRI"

def error_plot(clf):
    plt.plot(clf.history['train_auc'])
    plt.plot(clf.history['valid_auc'])

for i in range(3):
    error_plot(clfs[i])

plt.legend([f'train_{feature_names[0]}', f'valid_{feature_names[0]}', 
           f'train_{feature_names[1]}', f'valid_{feature_names[1]}',
           f'train_{feature_names[2]}', f'valid_{feature_names[2]}'])
plt.title(f'{simple_name}')
plt.xlabel('epochs')
plt.ylabel('AUC')
plt.tight_layout()

plt.savefig(f'AUC_per_epochs {simple_name}.png')

plt.show()          


feature_names=["combined", "psychosocial", "MRI"]
clfs = [clf_all, clf_pheno, clf_mri ]

def error_plot(clf):
    plt.plot(clf.history['loss'])

for i in range(3):
    error_plot(clfs[i])

plt.legend([f'{feature_names[0]}', 
           f'{feature_names[1]}',
           f'{feature_names[2]}'])
plt.title(f'{simple_name}')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.tight_layout()

plt.savefig(f'loss_per_epochs {simple_name}.png')

plt.show()

# %% [markdown]
# # Model save

# %%
def saveclf(clf,name):
    clf.save_model(f'{simple_name}_{name}')
saveclf(clf_all,"all")
saveclf(clf_pheno,"combined")
saveclf(clf_mri,"mri")
